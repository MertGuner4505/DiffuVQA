# %% [markdown]
# ## 1. Kurulum ve Bağımlılıklar

# %% [markdown]
# ## ⚙️ Konfigürasyon — Sadece bu hücreyi değiştir!
# Farklı bir branch veya dataset için **yalnızca aşağıdaki hücreyi** güncelle. Geri kalan tüm hücreler buradan okur.

# %%
# ============================================================
# PROJE KONFİGÜRASYONU — Branch değiştirince sadece burayı güncelle
# ============================================================

# --- GitHub & Drive ---
REPO_URL        = "https://github.com/panzerofthelake03/DiffuVQA.git"
BRANCH          = "Bio-Bert"
DRIVE_PROJECT_PATH = "/content/drive/MyDrive/DiffuVQA"
LOCAL_CLONE_PATH   = "/content/DiffuVQA"

# --- Model ---
MODEL_NAME      = "Bio-Bert"        # "bert" veya "pubmedbert" "Branch name"
MODEL_LABEL     = "DiffuVQA-Bert"  # Raporlarda görünecek isim

# --- Dataset ---
DATASET         = "daveKevin"             # "SLAKE", "Kvasir_VQA", "daveKevin" vb.
DATA_DIR        = "datasets"
DRIVE_IMAGE_DIR = f"{DRIVE_PROJECT_PATH}/datasets/imgs"
LOCAL_IMAGE_DIR = f"{LOCAL_CLONE_PATH}/datasets"

# Drive'daki dataset görüntü klasörü (birden fazla olası yol)
DATASET_IMG_PATHS = [
    f"/content/drive/MyDrive/datasets/{DATASET}/imgs/imgs",
    f"/content/drive/MyDrive/{DATASET}_dataset/imgs",
    f"/content/drive/Drive'ım/{DATASET}_dataset/imgs",
    f"/content/drive/MyDrive/{DATASET}/imgs",
    f"/content/drive/Drive'ım/{DATASET}/imgs",
]

# --- Eğitim ---
BATCH_SIZE      = 2
LR              = 0.0001
LEARNING_STEPS  = 1000
DIFFUSION_STEPS = 100
SEQ_LEN         = 128
HIDDEN_T_DIM    = 768
SEED            = 42
SAVE_INTERVAL   = 200
LOG_INTERVAL    = 50

# --- Checkpoint & Çıktı ---
CHECKPOINT_PATH = f"/content/drive/MyDrive/DiffuVQA/checkpoints/{DATASET.lower()}/{MODEL_NAME.lower()}/btch{BATCH_SIZE}/lr{LR}"
SAMPLE_FOLDER   = f"/content/drive/MyDrive/DiffuVQA/samples/{DATASET.lower()}/{MODEL_NAME.lower()}"
OUTPUT_CSV      = f"./reports/{MODEL_NAME}_{DATASET.lower()}_evaluation_results.csv"
DRIVE_RESULTS_PATH = "/content/drive/MyDrive/DiffuVQA_Results/"

print("✅ Konfigürasyon yüklendi:")
print(f"   Branch    : {BRANCH}  →  {REPO_URL}")
print(f"   Model     : {MODEL_NAME}")
print(f"   Dataset   : {DATASET}")
print(f"   Checkpoint: {CHECKPOINT_PATH}")
# Out:
# ✅ Konfigürasyon yüklendi:
#    Branch    : Bio-Bert  →  https://github.com/panzerofthelake03/DiffuVQA.git
#    Model     : Bio-Bert
#    Dataset   : daveKevin
#    Checkpoint: /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001

# %%
# GPU kontrolü
# !nvidia-smi
# Out:
# Wed Mar 11 21:14:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             16W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import shutil

# ADIM 1: Colab'daki geçici klasörü temizle (Taze indirme için şart)
if os.path.exists(LOCAL_CLONE_PATH):
    print(f"Eski geçici klasör siliniyor: {LOCAL_CLONE_PATH}")
    shutil.rmtree(LOCAL_CLONE_PATH)

# ADIM 2: GitHub'dan en güncel hali çek
print("GitHub'dan taze kopya çekiliyor...")
# !git clone -b {BRANCH} --single-branch {REPO_URL} {LOCAL_CLONE_PATH}

# ADIM 3: Drive'ı GÜNCELLE (dirs_exist_ok=True ile klasör olsa bile içine girip dosyaları yeniler)
print(f"Drive'daki dosyalar güncelleniyor: {DRIVE_PROJECT_PATH}")
if not os.path.exists(DRIVE_PROJECT_PATH):
    os.makedirs(DRIVE_PROJECT_PATH)

shutil.copytree(LOCAL_CLONE_PATH, DRIVE_PROJECT_PATH, dirs_exist_ok=True)
print("\n✅ İŞLEM TAMAM: Yeni dosyalar Drive'a geçti!")

# Çalışma dizinini Drive'daki projeye ayarla
os.chdir(DRIVE_PROJECT_PATH)
print(f"📂 Çalışma dizini: {os.getcwd()}")
# Out:
# Eski geçici klasör siliniyor: /content/DiffuVQA
# GitHub'dan taze kopya çekiliyor...
# Cloning into '/content/DiffuVQA'...
# remote: Enumerating objects: 814, done.
# remote: Counting objects: 100% (272/272), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 814 (delta 218), reused 207 (delta 196), pack-reused 542 (from 2)
# Receiving objects: 100% (814/814), 107.10 MiB | 13.03 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# Updating files: 100% (424/424), done.
# Drive'daki dosyalar güncelleniyor: /content/drive/MyDrive/DiffuVQA
#
# ✅ İŞLEM TAMAM: Yeni dosyalar Drive'a geçti!
# 📂 Çalışma dizini: /content/drive/MyDrive/DiffuVQA

# %%
# Mevcut bir Drive klonu varsa sadece güncelle (clone yerine alternatif)
if os.path.exists(DRIVE_PROJECT_PATH):
    os.chdir(DRIVE_PROJECT_PATH)
    print(f"📂 Çalışma dizini değiştirildi: {os.getcwd()}")
    print("⬇️ GitHub'dan güncellemeler çekiliyor (git pull)...")
    # !git pull
    print("\n✅ Güncelleme tamamlandı. İşte son 3 değişiklik:")
    # !git log -3 --oneline
else:
    print("❌ Hata: Drive'da proje klasörü bulunamadı. Önce yukarıdaki clone hücresini çalıştır.")
# Out:
# 📂 Çalışma dizini değiştirildi: /content/drive/MyDrive/DiffuVQA
# ⬇️ GitHub'dan güncellemeler çekiliyor (git pull)...
# Already up to date.
#
# ✅ Güncelleme tamamlandı. İşte son 3 değişiklik:
# 8d32ccf (HEAD -> Bio-Bert, origin/Bio-Bert) Update basic_utils.py
# 2e562bd Update basic_utils.py
# 732a09f Create run_diffuvqa_colab.ipynb

# %%
import os
import shutil
from tqdm.auto import tqdm

# Dataset-agnostic image directory resolution.
# Priority: existing local dataset folder -> candidate Drive paths -> fallback local datasets root.
def resolve_dataset_image_source(dataset_name, candidate_paths):
    for p in candidate_paths:
        if os.path.exists(p):
            return p
    return None

dataset_local_root = os.path.join(LOCAL_CLONE_PATH, "datasets")
dataset_local_imgs = os.path.join(dataset_local_root, "imgs")
source_image_path = resolve_dataset_image_source(DATASET, DATASET_IMG_PATHS)

# Default active image dir for all downstream cells.
ACTIVE_IMAGE_DIR = dataset_local_root

if DATASET.lower() == "slake":
    # SLAKE often needs explicit copy from Drive into local runtime storage.
    print(f"Checking SLAKE source path candidates: {DATASET_IMG_PATHS}")
    if source_image_path and os.path.exists(source_image_path):
        print(f"Using SLAKE source image path: {source_image_path}")
        os.makedirs(dataset_local_root, exist_ok=True)

        files_to_copy = []
        for root, _, files in os.walk(source_image_path):
            for file_name in files:
                src_file = os.path.join(root, file_name)
                rel_path = os.path.relpath(src_file, source_image_path)
                dst_file = os.path.join(dataset_local_root, rel_path)
                files_to_copy.append((src_file, dst_file))

        for src_file, dst_file in tqdm(files_to_copy, desc="Copying SLAKE files", unit="file"):
            os.makedirs(os.path.dirname(dst_file), exist_ok=True)
            shutil.copy2(src_file, dst_file)

        print("✅ SLAKE images copied successfully")
    else:
        print("⚠️ SLAKE source path not found in configured candidates; continuing with local dataset folder")
else:
    # For non-SLAKE datasets (e.g., davekevin), prefer existing local layout.
    if source_image_path:
        print(f"✅ Found dataset image source candidate: {source_image_path}")
    else:
        print("ℹ️ No external dataset image source found; using local dataset directory")

if os.path.exists(dataset_local_imgs):
    ACTIVE_IMAGE_DIR = dataset_local_imgs
elif os.path.exists(dataset_local_root):
    ACTIVE_IMAGE_DIR = dataset_local_root

print(f"📂 ACTIVE_IMAGE_DIR set to: {ACTIVE_IMAGE_DIR}")
# Out:
# ℹ️ No external dataset image source found; using local dataset directory
# 📂 ACTIVE_IMAGE_DIR set to: /content/DiffuVQA/datasets

# %%
# Dataset yapısını kontrol et
import os

active_image_dir = ACTIVE_IMAGE_DIR if "ACTIVE_IMAGE_DIR" in globals() else LOCAL_IMAGE_DIR

# !echo "📂 Dataset klasörü:"
# !ls -lh datasets/
# !echo "\n📊 JSONL dosyaları:"
# !ls -lh datasets/*.jsonl
print(f"\n🖼️ Active image dir: {active_image_dir}")
if os.path.exists(active_image_dir):
    try:
        print("İlk 5 dosya:")
        for i, name in enumerate(sorted(os.listdir(active_image_dir))[:5], 1):
            print(f"  {i}. {name}")
    except Exception as e:
        print(f"⚠️ Image dir listelenemedi: {e}")
else:
    print("⚠️ Active image dir bulunamadı.")

# !echo "\n📄 Train set örneği:"
# !head -n 1 datasets/train.jsonl
# Out:
# 📂 Dataset klasörü:
# total 2.1M
# drwx------ 3 root root 4.0K Mar 11 20:44 daveKevin_images
# drwx------ 2 root root 4.0K Nov 30 14:33 slake
# -rw------- 1 root root 324K Mar 11 21:15 test.jsonl
# -rw------- 1 root root 1.5M Mar 11 21:15 train.jsonl
# -rw------- 1 root root 322K Mar 11 21:15 valid.jsonl
# \n📊 JSONL dosyaları:
# -rw------- 1 root root 324K Mar 11 21:15 datasets/test.jsonl
# -rw------- 1 root root 1.5M Mar 11 21:15 datasets/train.jsonl
# -rw------- 1 root root 322K Mar 11 21:15 datasets/valid.jsonl
#
# 🖼️ Active image dir: /content/DiffuVQA/datasets
# İlk 5 dosya:
#   1. test.jsonl
#   2. train.jsonl
#   3. valid.jsonl
# \n📄 Train set örneği:
# {"img_id": 1, "img_name": "imgs/xmlab1/source.jpg", "question": "What modality is used to take this image?", "answer": "MRI", "q_lang": "en", "location": "Abdomen", "modality": "MRI", "answer_type": "OPEN", "base_type": "vqa", "content_type": "Modality", "triple": ["vhead", "_", "_"], "qid": 0}

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os
import random

# Use dataset-agnostic active image dir prepared in previous cell.
image_folder_path = ACTIVE_IMAGE_DIR if "ACTIVE_IMAGE_DIR" in globals() else LOCAL_IMAGE_DIR
print(f"Searching for images in: {image_folder_path}")

image_extensions = (".png", ".jpg", ".jpeg", ".gif", ".bmp", ".tiff")
all_image_files = []
for root, _, files in os.walk(image_folder_path):
    for file in files:
        if file.lower().endswith(image_extensions):
            all_image_files.append(os.path.join(root, file))

if not all_image_files:
    print(f"⚠️ No images found in {image_folder_path}. Please check path/config.")
else:
    print(f"Found {len(all_image_files)} images.")
    num_examples = min(5, len(all_image_files))
    selected_images = random.sample(all_image_files, num_examples)

    plt.figure(figsize=(15, 5))
    for i, img_path in enumerate(selected_images):
        try:
            img = Image.open(img_path)
            plt.subplot(1, num_examples, i + 1)
            plt.imshow(img)
            plt.title(os.path.basename(img_path), fontsize=8)
            plt.axis("off")
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            plt.subplot(1, num_examples, i + 1)
            plt.text(0.5, 0.5, "Error", horizontalalignment="center", verticalalignment="center", transform=plt.gca().transAxes, color="red")
            plt.axis("off")

    plt.tight_layout()
    plt.show()
    print(f"✅ Displayed {num_examples} example images.")
# Out:
# Searching for images in: /content/DiffuVQA/datasets
# ⚠️ No images found in /content/DiffuVQA/datasets. Please check path/config.

# %%
# vqa_datasets __main__ test (runs the module exactly like a script)
import os
import sys
import subprocess

# Ensure we run from project root
os.chdir(DRIVE_PROJECT_PATH)
print(f"cwd: {os.getcwd()}")

# Use dataset-agnostic image dir
data_dir = DATA_DIR
image_dir = ACTIVE_IMAGE_DIR if "ACTIVE_IMAGE_DIR" in globals() else LOCAL_IMAGE_DIR
dataset_name = DATASET

cmd = [
    sys.executable,
    "-m",
    "diffuvqa.vqa_datasets",
    "--data_dir", data_dir,
    "--dataset", dataset_name,
    "--image_dir", image_dir,
    "--vocab", MODEL_NAME.lower(),
    "--config_name", "bert-base-uncased" if MODEL_NAME.lower() == "bert" else MODEL_NAME,
    "--batch_size", "1",
    "--seq_len", "64",
    "--image_size", "224",
]

print("Running command:")
print(" ".join(cmd))
print("-" * 80)

result = subprocess.run(cmd, text=True, capture_output=True)
print(result.stdout)
if result.stderr:
    print("[stderr]")
    print(result.stderr)

print("-" * 80)
print(f"Return code: {result.returncode}")
if result.returncode != 0:
    print("vqa_datasets __main__ test failed. Check logs above for missing path/dependency details.")
else:
    print("vqa_datasets __main__ test completed successfully.")
# Out:
# cwd: /content/drive/MyDrive/DiffuVQA
# Running command:
# /usr/bin/python3 -m diffuvqa.vqa_datasets --data_dir datasets --dataset daveKevin --image_dir /content/DiffuVQA/datasets --vocab bio-bert --config_name Bio-Bert --batch_size 1 --seq_len 64 --image_size 224
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15492/1752975885.py in <cell line: 0>()
#      31 print("-" * 80)
#      32
# ---> 33 result = subprocess.run(cmd, text=True, capture_output=True)
#      34 print(result.stdout)
#      35 if result.stderr:
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
# Bağımlılıkları yükle
# Colab PyTorch ile geliyor, o yüzden requirements_colab.txt kullanıyoruz
# !pip install --upgrade pip
# !pip install -r requirements_colab.txt
# !pip install pandas openpyxl bert-score  # Excel support ve BERTScore için
# !python -m spacy download en_core_web_sm

print("\n✅ Kurulum tamamlandı!")
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.0.1)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 5)) (4.0.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 6)) (0.2.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 7)) (1.5.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 8)) (1.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 11)) (2.0.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 12)) (18.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 13)) (1.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 14)) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 15)) (4.67.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 16)) (26.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 17)) (2.2.2)
# Requirement already satisfied: openpyxl>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 18)) (3.1.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 21)) (11.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 24)) (3.9.1)
# Requirement already satisfied: bert_score in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 25)) (0.3.13)
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 26)) (1.2)
# Requirement already satisfied: spacy>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 27)) (3.8.11)
# Requirement already satisfied: blobfile in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 30)) (3.2.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 33)) (0.25.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 36)) (6.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 37)) (75.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 38)) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->-r requirements_colab.txt (line 5)) (3.25.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->-r requirements_colab.txt (line 5)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->-r requirements_colab.txt (line 5)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->-r requirements_colab.txt (line 5)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->-r requirements_colab.txt (line 5)) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements_colab.txt (line 7)) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements_colab.txt (line 7)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements_colab.txt (line 7)) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements_colab.txt (line 7)) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements_colab.txt (line 7)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements_colab.txt (line 7)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements_colab.txt (line 7)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->-r requirements_colab.txt (line 7)) (0.16.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements_colab.txt (line 8)) (2.10.0+cu128)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements_colab.txt (line 8)) (0.7.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements_colab.txt (line 13)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements_colab.txt (line 13)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements_colab.txt (line 13)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements_colab.txt (line 17)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements_colab.txt (line 17)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements_colab.txt (line 17)) (2025.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.0.0->-r requirements_colab.txt (line 18)) (2.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->-r requirements_colab.txt (line 24)) (8.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->-r requirements_colab.txt (line 24)) (2025.11.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score->-r requirements_colab.txt (line 25)) (5.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert_score->-r requirements_colab.txt (line 25)) (3.10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from pycocoevalcap->-r requirements_colab.txt (line 26)) (2.0.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (0.24.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->-r requirements_colab.txt (line 27)) (3.1.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (2.5.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (0.1.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (2.1.1)
# Requirement already satisfied: pycryptodomex>=3.8 in /usr/local/lib/python3.12/dist-packages (from blobfile->-r requirements_colab.txt (line 30)) (3.23.0)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.12/dist-packages (from blobfile->-r requirements_colab.txt (line 30)) (6.0.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements_colab.txt (line 33)) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements_colab.txt (line 33)) (4.9.4)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements_colab.txt (line 33)) (5.29.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements_colab.txt (line 33)) (2.54.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.0.0->-r requirements_colab.txt (line 5)) (1.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements_colab.txt (line 33)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements_colab.txt (line 33)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements_colab.txt (line 17)) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (3.6.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate->-r requirements_colab.txt (line 8)) (1.3.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score->-r requirements_colab.txt (line 25)) (0.22.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->-r requirements_colab.txt (line 7)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->-r requirements_colab.txt (line 7)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->-r requirements_colab.txt (line 7)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->-r requirements_colab.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->-r requirements_colab.txt (line 7)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub->-r requirements_colab.txt (line 7)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy>=3.4.0->-r requirements_colab.txt (line 27)) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score->-r requirements_colab.txt (line 25)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score->-r requirements_colab.txt (line 25)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score->-r requirements_colab.txt (line 25)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score->-r requirements_colab.txt (line 25)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score->-r requirements_colab.txt (line 25)) (3.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.10.0+cu128)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (5.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.67.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.0.0->bert-score) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (1.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.5.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert-score) (0.1.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 127.2 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
#
# ✅ Kurulum tamamlandı!

# %%
# Gerekli kütüphaneleri içe aktar
import os
import sys
import json
import torch
import pandas as pd
import numpy as np
from datetime import datetime
from collections import defaultdict
import glob

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# !pip install torchmetrics
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# CUDA device: Tesla T4
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (26.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.10.0+cu128)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.15.3->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->torchmetrics) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)

# %% [markdown]
# ## 2. Model Eğitimi

# %%
import os
os.makedirs(CHECKPOINT_PATH, exist_ok=True)
MODEL = f"transformer-{MODEL_NAME.lower()}"
train_image_dir = ACTIVE_IMAGE_DIR if "ACTIVE_IMAGE_DIR" in globals() else LOCAL_IMAGE_DIR
print(f"Training with image_dir: {train_image_dir}")

# !python train.py \
    --vocab {MODEL_NAME.lower()} \
    --model {MODEL} \
    --use_plm_init {MODEL_NAME} \
    --batch_size {BATCH_SIZE} \
    --lr {LR} \
    --diffusion_steps {DIFFUSION_STEPS} \
    --seq_len {SEQ_LEN} \
    --hidden_t_dim {HIDDEN_T_DIM} \
    --checkpoint_path {CHECKPOINT_PATH} \
    --seed {SEED} \
    --learning_steps {LEARNING_STEPS} \
    --save_interval {SAVE_INTERVAL} \
    --log_interval {LOG_INTERVAL} \
    --data_dir {DATA_DIR} \
    --dataset {DATASET} \
    --image_dir {train_image_dir}
# Out:
# Training with image_dir: /content/DiffuVQA/datasets
# Logging to /tmp/openai-2026-03-11-21-19-36-504185
# ### Creating data loader...
# save tokenizer to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001
# initializing the random embeddings Embedding(28996, 768)
# ##############################
# Loading text data...
# ##############################
# Loading dataset daveKevin from datasets...
# ### Loading DaveKevin/MedVQA dataset from HuggingFace...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Resolving data files: 100% 20/20 [00:00<00:00, 115704.94it/s]
# Resolving data files: 100% 20/20 [00:00<00:00, 143395.01it/s]
# Loading dataset shards: 100% 19/19 [00:00<00:00, 69.37it/s]
# ### Using samples 0-13228 for TRAIN set...
# ### Found cached images in datasets/daveKevin_images/train, skipping download...
# ### Processing 13228 samples from DaveKevin/MedVQA...
# ### Processed 0/13228 samples...
# ### Processed 500/13228 samples...
# ### Processed 1000/13228 samples...
# ### Processed 1500/13228 samples...
# ### Processed 2000/13228 samples...
# ### Processed 2500/13228 samples...
# ### Processed 3000/13228 samples...
# ### Processed 3500/13228 samples...
# ### Processed 4000/13228 samples...
# ### Processed 4500/13228 samples...
# ### Processed 5000/13228 samples...
# ### Processed 5500/13228 samples...
# ### Processed 6000/13228 samples...
# ### Processed 6500/13228 samples...
# ### Processed 7000/13228 samples...
# ### Processed 7500/13228 samples...
# ### Processed 8000/13228 samples...
# ### Processed 8500/13228 samples...
# ### Processed 9000/13228 samples...
# ### Processed 9500/13228 samples...
# ### Processed 10000/13228 samples...
# ### Processed 10500/13228 samples...
# ### Processed 11000/13228 samples...
# ### Processed 11500/13228 samples...
# ### Processed 12000/13228 samples...
# ### Processed 12500/13228 samples...
# ### Processed 13000/13228 samples...
# ### Finished processing DaveKevin/MedVQA train set
# ### Data samples...
# questions: ['What does the CT angiography image show?', 'What does the arrow in the image indicate?'] answers: ['The CT angiography image shows an anomalous arterial supply to the normal lung tissue contiguous with sequestration.', 'The arrow points to the anomalous arterial supply to the normal lung tissue.'] images: ['train/medvqa_train_000000.png', 'train/medvqa_train_000001.png']
# Attempted image path: datasets/daveKevin_images/train/medvqa_train_000000.png
# Parent folder of attempted image path: datasets/daveKevin_images/train
# Inside parent folder (datasets/daveKevin_images/train): ['medvqa_train_000000.png', 'medvqa_train_000001.png', 'medvqa_train_000002.png', 'medvqa_train_000003.png', 'medvqa_train_000004.png', 'medvqa_train_000005.png', 'medvqa_train_000006.png', 'medvqa_train_000007.png', 'medvqa_train_000008.png', 'medvqa_train_000009.png', 'medvqa_train_000010.png', 'medvqa_train_000011.png', 'medvqa_train_000012.png', 'medvqa_train_000013.png', 'medvqa_train_000014.png', 'medvqa_train_000015.png', 'medvqa_train_000016.png', 'medvqa_train_000017.png', 'medvqa_train_000018.png', 'medvqa_train_000019.png', 'medvqa_train_000020.png', 'medvqa_train_000021.png', 'medvqa_train_000022.png', 'medvqa_train_000023.png', 'medvqa_train_000024.png', 'medvqa_train_000025.png', 'medvqa_train_000026.png', 'medvqa_train_000027.png', 'medvqa_train_000028.png', 'medvqa_train_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/train/medvqa_train_000000.png
# Attempted image path: datasets/daveKevin_images/train/medvqa_train_000001.png
# Parent folder of attempted image path: datasets/daveKevin_images/train
# Inside parent folder (datasets/daveKevin_images/train): ['medvqa_train_000000.png', 'medvqa_train_000001.png', 'medvqa_train_000002.png', 'medvqa_train_000003.png', 'medvqa_train_000004.png', 'medvqa_train_000005.png', 'medvqa_train_000006.png', 'medvqa_train_000007.png', 'medvqa_train_000008.png', 'medvqa_train_000009.png', 'medvqa_train_000010.png', 'medvqa_train_000011.png', 'medvqa_train_000012.png', 'medvqa_train_000013.png', 'medvqa_train_000014.png', 'medvqa_train_000015.png', 'medvqa_train_000016.png', 'medvqa_train_000017.png', 'medvqa_train_000018.png', 'medvqa_train_000019.png', 'medvqa_train_000020.png', 'medvqa_train_000021.png', 'medvqa_train_000022.png', 'medvqa_train_000023.png', 'medvqa_train_000024.png', 'medvqa_train_000025.png', 'medvqa_train_000026.png', 'medvqa_train_000027.png', 'medvqa_train_000028.png', 'medvqa_train_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/train/medvqa_train_000001.png
# Attempted image path: datasets/daveKevin_images/train/medvqa_train_000002.png
# Parent folder of attempted image path: datasets/daveKevin_images/train
# Inside parent folder (datasets/daveKevin_images/train): ['medvqa_train_000000.png', 'medvqa_train_000001.png', 'medvqa_train_000002.png', 'medvqa_train_000003.png', 'medvqa_train_000004.png', 'medvqa_train_000005.png', 'medvqa_train_000006.png', 'medvqa_train_000007.png', 'medvqa_train_000008.png', 'medvqa_train_000009.png', 'medvqa_train_000010.png', 'medvqa_train_000011.png', 'medvqa_train_000012.png', 'medvqa_train_000013.png', 'medvqa_train_000014.png', 'medvqa_train_000015.png', 'medvqa_train_000016.png', 'medvqa_train_000017.png', 'medvqa_train_000018.png', 'medvqa_train_000019.png', 'medvqa_train_000020.png', 'medvqa_train_000021.png', 'medvqa_train_000022.png', 'medvqa_train_000023.png', 'medvqa_train_000024.png', 'medvqa_train_000025.png', 'medvqa_train_000026.png', 'medvqa_train_000027.png', 'medvqa_train_000028.png', 'medvqa_train_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/train/medvqa_train_000002.png
# ### Saved sample preview to datasets/daveKevin_train_first3_preview.png
# Figure(1500x500)
# RAM used: 3243.54 MB
# Dataset size: 13228
# Tokenized 512 / 13228 -- RAM: 3249.20 MB
# Tokenized 1024 / 13228 -- RAM: 3257.02 MB
# Tokenized 1536 / 13228 -- RAM: 3259.02 MB
# Tokenized 2048 / 13228 -- RAM: 3260.49 MB
# Tokenized 2560 / 13228 -- RAM: 3262.09 MB
# Tokenized 3072 / 13228 -- RAM: 3263.64 MB
# Tokenized 3584 / 13228 -- RAM: 3264.78 MB
# Tokenized 4096 / 13228 -- RAM: 3265.04 MB
# Tokenized 4608 / 13228 -- RAM: 3266.04 MB
# Tokenized 5120 / 13228 -- RAM: 3267.09 MB
# Tokenized 5632 / 13228 -- RAM: 3267.60 MB
# Tokenized 6144 / 13228 -- RAM: 3268.18 MB
# Tokenized 6656 / 13228 -- RAM: 3269.61 MB
# Tokenized 7168 / 13228 -- RAM: 3271.31 MB
# Tokenized 7680 / 13228 -- RAM: 3272.73 MB
# Tokenized 8192 / 13228 -- RAM: 3274.39 MB
# Tokenized 8704 / 13228 -- RAM: 3275.85 MB
# Tokenized 9216 / 13228 -- RAM: 3277.42 MB
# Tokenized 9728 / 13228 -- RAM: 3279.04 MB
# Tokenized 10240 / 13228 -- RAM: 3280.55 MB
# Tokenized 10752 / 13228 -- RAM: 3282.18 MB
# Tokenized 11264 / 13228 -- RAM: 3283.99 MB
# Tokenized 11776 / 13228 -- RAM: 3285.35 MB
# Tokenized 12288 / 13228 -- RAM: 3286.96 MB
# Tokenized 12800 / 13228 -- RAM: 3288.68 MB
# Tokenized 13228 / 13228 -- RAM: 3287.52 MB
# Finished tokenization. RAM used: 3379.30 MB
# ##############################
# Loading text data...
# ##############################
# Loading dataset daveKevin from datasets...
# ### Loading DaveKevin/MedVQA dataset from HuggingFace...
# Resolving data files: 100% 20/20 [00:00<00:00, 28197.00it/s]
# Resolving data files: 100% 20/20 [00:00<00:00, 54436.13it/s]
# Loading dataset shards: 100% 19/19 [00:00<00:00, 37.38it/s]
# ### Using samples 13228-14881 for VALID set...
# ### Processing 1653 samples from DaveKevin/MedVQA...
# ### Processed 0/1653 samples...
# ### Processed 500/1653 samples...
# ### Processed 1000/1653 samples...
# ### Processed 1500/1653 samples...
# ### Finished processing DaveKevin/MedVQA valid set
# ### Data samples...
# questions: ['What are liver abscesses?', 'What is mesenteric partial thrombosis?'] answers: ['Liver abscesses are pockets of pus that form in the liver, often due to infection.', 'Mesenteric partial thrombosis refers to a blood clot that partially blocks blood flow in the mesenteric arteries, which supply blood to the intestines.'] images: ['valid/medvqa_valid_000000.png', 'valid/medvqa_valid_000001.png']
# Attempted image path: datasets/daveKevin_images/valid/medvqa_valid_000000.png
# Parent folder of attempted image path: datasets/daveKevin_images/valid
# Inside parent folder (datasets/daveKevin_images/valid): ['medvqa_valid_000000.png', 'medvqa_valid_000001.png', 'medvqa_valid_000002.png', 'medvqa_valid_000003.png', 'medvqa_valid_000004.png', 'medvqa_valid_000005.png', 'medvqa_valid_000006.png', 'medvqa_valid_000007.png', 'medvqa_valid_000008.png', 'medvqa_valid_000009.png', 'medvqa_valid_000010.png', 'medvqa_valid_000011.png', 'medvqa_valid_000012.png', 'medvqa_valid_000013.png', 'medvqa_valid_000014.png', 'medvqa_valid_000015.png', 'medvqa_valid_000016.png', 'medvqa_valid_000017.png', 'medvqa_valid_000018.png', 'medvqa_valid_000019.png', 'medvqa_valid_000020.png', 'medvqa_valid_000021.png', 'medvqa_valid_000022.png', 'medvqa_valid_000023.png', 'medvqa_valid_000024.png', 'medvqa_valid_000025.png', 'medvqa_valid_000026.png', 'medvqa_valid_000027.png', 'medvqa_valid_000028.png', 'medvqa_valid_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/valid/medvqa_valid_000000.png
# Attempted image path: datasets/daveKevin_images/valid/medvqa_valid_000001.png
# Parent folder of attempted image path: datasets/daveKevin_images/valid
# Inside parent folder (datasets/daveKevin_images/valid): ['medvqa_valid_000000.png', 'medvqa_valid_000001.png', 'medvqa_valid_000002.png', 'medvqa_valid_000003.png', 'medvqa_valid_000004.png', 'medvqa_valid_000005.png', 'medvqa_valid_000006.png', 'medvqa_valid_000007.png', 'medvqa_valid_000008.png', 'medvqa_valid_000009.png', 'medvqa_valid_000010.png', 'medvqa_valid_000011.png', 'medvqa_valid_000012.png', 'medvqa_valid_000013.png', 'medvqa_valid_000014.png', 'medvqa_valid_000015.png', 'medvqa_valid_000016.png', 'medvqa_valid_000017.png', 'medvqa_valid_000018.png', 'medvqa_valid_000019.png', 'medvqa_valid_000020.png', 'medvqa_valid_000021.png', 'medvqa_valid_000022.png', 'medvqa_valid_000023.png', 'medvqa_valid_000024.png', 'medvqa_valid_000025.png', 'medvqa_valid_000026.png', 'medvqa_valid_000027.png', 'medvqa_valid_000028.png', 'medvqa_valid_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/valid/medvqa_valid_000001.png
# Attempted image path: datasets/daveKevin_images/valid/medvqa_valid_000002.png
# Parent folder of attempted image path: datasets/daveKevin_images/valid
# Inside parent folder (datasets/daveKevin_images/valid): ['medvqa_valid_000000.png', 'medvqa_valid_000001.png', 'medvqa_valid_000002.png', 'medvqa_valid_000003.png', 'medvqa_valid_000004.png', 'medvqa_valid_000005.png', 'medvqa_valid_000006.png', 'medvqa_valid_000007.png', 'medvqa_valid_000008.png', 'medvqa_valid_000009.png', 'medvqa_valid_000010.png', 'medvqa_valid_000011.png', 'medvqa_valid_000012.png', 'medvqa_valid_000013.png', 'medvqa_valid_000014.png', 'medvqa_valid_000015.png', 'medvqa_valid_000016.png', 'medvqa_valid_000017.png', 'medvqa_valid_000018.png', 'medvqa_valid_000019.png', 'medvqa_valid_000020.png', 'medvqa_valid_000021.png', 'medvqa_valid_000022.png', 'medvqa_valid_000023.png', 'medvqa_valid_000024.png', 'medvqa_valid_000025.png', 'medvqa_valid_000026.png', 'medvqa_valid_000027.png', 'medvqa_valid_000028.png', 'medvqa_valid_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/valid/medvqa_valid_000002.png
# ### Saved sample preview to datasets/daveKevin_valid_first3_preview.png
# Figure(1500x500)
# RAM used: 2164.48 MB
# Dataset size: 1653
# Tokenized 512 / 1653 -- RAM: 2164.48 MB
# Tokenized 1024 / 1653 -- RAM: 2164.50 MB
# Tokenized 1536 / 1653 -- RAM: 2164.51 MB
# Tokenized 1653 / 1653 -- RAM: 2164.51 MB
# Finished tokenization. RAM used: 2182.77 MB
# ############################## size of vocab 28996
# ### Creating model and diffusion...
# usetransformer-bio-bert
# initializing from pretrained bert...
# BertConfig {
#   "add_cross_attention": false,
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "classifier_dropout": null,
#   "eos_token_id": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.0.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# pytorch_model.bin: 100% 433M/433M [00:02<00:00, 179MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1486.03it/s, Materializing param=pooler.dense.weight]
#   0%|                                               | 0.00/354M [00:00<?, ?iB/s]
#   4%|█▋                                     | 15.0M/354M [00:00<00:02, 150MiB/s]
#   8%|███▏                                  | 29.9M/354M [00:00<00:03, 98.5MiB/s]
#  14%|█████▍                                | 50.3M/354M [00:00<00:03, 88.3MiB/s]
#  17%|██████▎                               | 59.4M/354M [00:00<00:03, 88.2MiB/s]
#  20%|███████▋                              | 71.3M/354M [00:00<00:02, 97.4MiB/s]
#  26%|█████████▊                            | 90.9M/354M [00:00<00:02, 88.6MiB/s]
#  28%|███████████                            | 100M/354M [00:01<00:03, 78.3MiB/s]
#  31%|███████████▉                           | 108M/354M [00:01<00:03, 71.6MiB/s]
#  34%|█████████████▏                         | 119M/354M [00:01<00:02, 81.6MiB/s]
#  36%|██████████████▏                        | 128M/354M [00:01<00:02, 83.9MiB/s]
#  41%|███████████████▉                       | 145M/354M [00:01<00:02, 73.5MiB/s]
#  44%|█████████████████▏                     | 155M/354M [00:01<00:02, 82.0MiB/s]
#  49%|██████████████████▉                    | 172M/354M [00:02<00:02, 76.6MiB/s]
#  51%|███████████████████▊                   | 180M/354M [00:02<00:02, 70.9MiB/s]
#  56%|█████████████████████▉                 | 199M/354M [00:02<00:02, 65.7MiB/s]
#  61%|███████████████████████▋               | 215M/354M [00:02<00:01, 69.8MiB/s]
#  67%|██████████████████████████▏            | 238M/354M [00:02<00:01, 91.5MiB/s]
#  70%|███████████████████████████▏           | 247M/354M [00:03<00:01, 84.9MiB/s]
#  73%|████████████████████████████▍          | 258M/354M [00:03<00:01, 89.9MiB/s]
# model.safetensors:  92% 398M/433M [00:03<00:00, 111MB/s]
# model.safetensors: 100% 433M/433M [00:03<00:00, 125MB/s]
# 100%|███████████████████████████████████████| 354M/354M [00:04<00:00, 84.9MiB/s]
# ### The parameter count is 224142023
# ### Saving the hyperparameters to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/training_args.json
# wandb: Tracking run with wandb version 0.25.0
# wandb: W&B syncing is set to `offline` in this directory. Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# wandb: Run data is saved locally in /content/drive/MyDrive/DiffuVQA/wandb/offline-run-20260311_222125-9qu7d1ed
# ### Training...
# Device: cuda
# Training:  20% 200/1000 [02:16<09:32,  1.40step/s, loss=10.1664, lr=8.020e-05]saving model 0.9999...
# writing to /tmp/openai-2026-03-11-21-19-36-504185/ema_0.9999_000200.pt
# writing to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_000200.pt
# Training:  40% 400/1000 [04:41<06:51,  1.46step/s, loss=10.4928, lr=6.020e-05]saving model 0.9999...
# writing to /tmp/openai-2026-03-11-21-19-36-504185/ema_0.9999_000400.pt
# writing to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_000400.pt
# Training:  60% 600/1000 [07:05<04:46,  1.40step/s, loss=9.6823, lr=4.020e-05]saving model 0.9999...
# writing to /tmp/openai-2026-03-11-21-19-36-504185/ema_0.9999_000600.pt
# writing to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_000600.pt
# Training:  80% 800/1000 [09:30<02:16,  1.47step/s, loss=8.9171, lr=2.020e-05]saving model 0.9999...
# writing to /tmp/openai-2026-03-11-21-19-36-504185/ema_0.9999_000800.pt
# writing to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_000800.pt
# Training: 100% 1000/1000 [11:53<00:00,  1.40step/s, loss=7.7354, lr=1.000e-07]
# saving model 0.9999...
# writing to /tmp/openai-2026-03-11-21-19-36-504185/ema_0.9999_001000.pt
# writing to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# ✅ Training logs recorded in reports/training_logs.xlsx
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/drive/MyDrive/DiffuVQA/wandb/offline-run-20260311_222125-9qu7d1ed
# wandb: Find logs at: wandb/offline-run-20260311_222125-9qu7d1ed/logs

# %% [markdown]
# ## 3. Model Örnekleme (Inference)

# %%
# Test seti üzerinde örnekleme yap
# Checkpoint dosyasını otomatik bul
checkpoint_files = sorted(glob.glob(f"{CHECKPOINT_PATH}/ema_*.pt"))
SAMPLE_STEP = 50
SAMPLE_SEED2 = 105

if checkpoint_files:
    checkpoint_file = checkpoint_files[-1]
    print(f"📂 Kullanılacak checkpoint: {checkpoint_file}")
else:
    print("⚠️ Checkpoint bulunamadı! Lütfen önce eğitimi tamamlayın.")
    checkpoint_file = None

if checkpoint_file:
    # !python sample_vqa_GPU.py \
        --model_path {checkpoint_file} \
        --step {SAMPLE_STEP} \
        --batch_size {BATCH_SIZE} \
        --seed2 {SAMPLE_SEED2} \
        --split test \
        --out_dir {SAMPLE_FOLDER} \
        --clamp_step 0

    print(f"\n✅ Örnekleme tamamlandı!")
    print(f"📂 Çıktı dosyaları {SAMPLE_FOLDER} klasöründe oluşturuldu.")
    # !echo "\n📄 Oluşturulan sample dosyaları:"
    # !ls -lh {SAMPLE_FOLDER}*.jsonl | tail -5
# Out:
# 📂 Kullanılacak checkpoint: /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# Logging to /tmp/openai-2026-03-11-22-40-26-120346
# DEBUG: Parsed model_path = /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# ### Loading model from /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# config_path: /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/training_args.json
# ### Updated args: Namespace(model_path='/content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt', step=50, out_dir='/content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert', top_p=0, lr=0.0001, batch_size=2, learning_steps=1000, microbatch=64, log_interval=50, save_interval=200, eval_interval=500, valid=True, ema_rate='0.9999', resume_checkpoint='none', schedule_sampler='lossaware', diffusion_steps=100, noise_schedule='sqrt', timestep_respacing=[100], vocab='bio-bert', use_plm_init='Bio-Bert', vocab_size=28996, config_name='bert-base-uncased', notes='folder-notes', data_dir='datasets', dataset='daveKevin', image_dir='/content/DiffuVQA/datasets', checkpoint_path='/content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001', image_encoder='ViT-B/32', image_resolution=384, input_dims=128, seq_len=128, hidden_t_dim=768, hidden_v_dim=768, hidden_dim=768, hidden_size=768, extend_hidden_size=1024, output_dims=512, total_answers_num=557, dropout=0.2, use_fp16=False, fp16_scale_growth=0.001, seed=42, gradient_clipping=0.5, weight_decay=0.0, learn_sigma=False, use_kl=False, predict_xstart=True, rescale_timesteps=True, rescale_learned_sigmas=False, use_resnet152=False, sigma_small=False, emb_scale_factor=1.0, input_text_embed_size=768, input_image_embed_size=768, language_encoder_name='bert-base-uncased', num_heads=8, num_layers=6, d_model=768, num_encoder_layers=6, num_top_layer=6, dim_feedforward=2048, feature_size=768, model='transformer-bio-bert', mlp_ratio=4, split='test', clamp_step=0, seed2=105, clip_denoised=False, use_noising_f=False)
# >>> diffusion_steps before: 50
# ### Creating model and diffusion...
# initializing from pretrained bert...
# BertConfig {
#   "add_cross_attention": false,
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "classifier_dropout": null,
#   "eos_token_id": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.0.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# Loading weights: 100% 199/199 [00:00<00:00, 1008.73it/s, Materializing param=pooler.dense.weight]
# ### The parameter count is 224142023
# save tokenizer to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001
# ### Sampling...on test
# batch_size=2
# ##############################
# Loading text data...
# ##############################
# Loading dataset daveKevin from datasets...
# ### Loading DaveKevin/MedVQA dataset from HuggingFace...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Resolving data files: 100% 20/20 [00:00<00:00, 151692.73it/s]
# Resolving data files: 100% 20/20 [00:00<00:00, 176602.27it/s]
# Loading dataset shards: 100% 19/19 [00:00<00:00, 85.04it/s]
# ### Using samples 14881-16536 for TEST set...
# ### Processing 1655 samples from DaveKevin/MedVQA...
# ### Processed 0/1655 samples...
# ### Processed 500/1655 samples...
# ### Processed 1000/1655 samples...
# ### Processed 1500/1655 samples...
# ### Finished processing DaveKevin/MedVQA test set
# ### Data samples...
# questions: ['What does the arrow pointing to in the image represent?', 'What is ulnar neuritis?'] answers: ['The arrow points to the ulnar nerve in the cubital tunnel, showing findings consistent with ulnar neuritis.', 'Ulnar neuritis is inflammation of the ulnar nerve, which can cause symptoms such as pain, numbness, and weakness in the hand and arm.'] images: ['test/medvqa_test_000000.png', 'test/medvqa_test_000001.png']
# Attempted image path: datasets/daveKevin_images/test/medvqa_test_000000.png
# Parent folder of attempted image path: datasets/daveKevin_images/test
# Inside parent folder (datasets/daveKevin_images/test): ['medvqa_test_000000.png', 'medvqa_test_000001.png', 'medvqa_test_000002.png', 'medvqa_test_000003.png', 'medvqa_test_000004.png', 'medvqa_test_000005.png', 'medvqa_test_000006.png', 'medvqa_test_000007.png', 'medvqa_test_000008.png', 'medvqa_test_000009.png', 'medvqa_test_000010.png', 'medvqa_test_000011.png', 'medvqa_test_000012.png', 'medvqa_test_000013.png', 'medvqa_test_000014.png', 'medvqa_test_000015.png', 'medvqa_test_000016.png', 'medvqa_test_000017.png', 'medvqa_test_000018.png', 'medvqa_test_000019.png', 'medvqa_test_000020.png', 'medvqa_test_000021.png', 'medvqa_test_000022.png', 'medvqa_test_000023.png', 'medvqa_test_000024.png', 'medvqa_test_000025.png', 'medvqa_test_000026.png', 'medvqa_test_000027.png', 'medvqa_test_000028.png', 'medvqa_test_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/test/medvqa_test_000000.png
# Attempted image path: datasets/daveKevin_images/test/medvqa_test_000001.png
# Parent folder of attempted image path: datasets/daveKevin_images/test
# Inside parent folder (datasets/daveKevin_images/test): ['medvqa_test_000000.png', 'medvqa_test_000001.png', 'medvqa_test_000002.png', 'medvqa_test_000003.png', 'medvqa_test_000004.png', 'medvqa_test_000005.png', 'medvqa_test_000006.png', 'medvqa_test_000007.png', 'medvqa_test_000008.png', 'medvqa_test_000009.png', 'medvqa_test_000010.png', 'medvqa_test_000011.png', 'medvqa_test_000012.png', 'medvqa_test_000013.png', 'medvqa_test_000014.png', 'medvqa_test_000015.png', 'medvqa_test_000016.png', 'medvqa_test_000017.png', 'medvqa_test_000018.png', 'medvqa_test_000019.png', 'medvqa_test_000020.png', 'medvqa_test_000021.png', 'medvqa_test_000022.png', 'medvqa_test_000023.png', 'medvqa_test_000024.png', 'medvqa_test_000025.png', 'medvqa_test_000026.png', 'medvqa_test_000027.png', 'medvqa_test_000028.png', 'medvqa_test_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/test/medvqa_test_000001.png
# Attempted image path: datasets/daveKevin_images/test/medvqa_test_000002.png
# Parent folder of attempted image path: datasets/daveKevin_images/test
# Inside parent folder (datasets/daveKevin_images/test): ['medvqa_test_000000.png', 'medvqa_test_000001.png', 'medvqa_test_000002.png', 'medvqa_test_000003.png', 'medvqa_test_000004.png', 'medvqa_test_000005.png', 'medvqa_test_000006.png', 'medvqa_test_000007.png', 'medvqa_test_000008.png', 'medvqa_test_000009.png', 'medvqa_test_000010.png', 'medvqa_test_000011.png', 'medvqa_test_000012.png', 'medvqa_test_000013.png', 'medvqa_test_000014.png', 'medvqa_test_000015.png', 'medvqa_test_000016.png', 'medvqa_test_000017.png', 'medvqa_test_000018.png', 'medvqa_test_000019.png', 'medvqa_test_000020.png', 'medvqa_test_000021.png', 'medvqa_test_000022.png', 'medvqa_test_000023.png', 'medvqa_test_000024.png', 'medvqa_test_000025.png', 'medvqa_test_000026.png', 'medvqa_test_000027.png', 'medvqa_test_000028.png', 'medvqa_test_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/test/medvqa_test_000002.png
# ### Saved sample preview to datasets/daveKevin_test_first3_preview.png
# Figure(1500x500)
# RAM used: 3589.71 MB
# Dataset size: 1655
# Tokenized 512 / 1655 -- RAM: 3604.09 MB
# Tokenized 1024 / 1655 -- RAM: 3611.09 MB
# Tokenized 1536 / 1655 -- RAM: 3612.02 MB
# Tokenized 1655 / 1655 -- RAM: 3612.03 MB
# Finished tokenization. RAM used: 3629.80 MB
# <<<<model_base_name: lr0.0001.ema_0.9999_001000.pt
# <<<<args.model_path: /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# <<<<<checkpoint_name: ema_0.9999_001000.pt
# out_path: /content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert/ema_0.9999_001000.pt.seed102_step0_samplestep50_bsize2.jsonl
# batch_size: 2
# Loading test data: 100% 827/827 [01:32<00:00,  8.96it/s]
# Sampling: 100% 827/827 [2:14:56<00:00,  9.79s/it]
# Sampling data recorded in reports/sampling_records.xlsx
# ### Recorded sampling data: {'model_path': '/content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt', 'dataset': 'daveKevin', 'batch_size': 2, 'top_p': 0, 'seed': 102, 'sampling_steps': 50, 'total_samples': 1654, 'sampling_duration_in_seconds': 8189.048267364502}
# ### Total takes 8190.11s .....
# ### Written the decoded output to /content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert/ema_0.9999_001000.pt.seed102_step0_samplestep50_bsize2.jsonl
#
# ✅ Örnekleme tamamlandı!
# 📂 Çıktı dosyaları /content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert klasöründe oluşturuldu.
# \n📄 Oluşturulan sample dosyaları:
# ls: cannot access '/content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert*.jsonl': No such file or directory

# %%
# compare_image_black_vectors.py hızlı test hücresi (dataset-safe + import-safe + error-aware)
import glob
import os
import sys
import subprocess

# Komutu proje kökünden çalıştır ki `diffuvqa` import'u çözülsün
os.chdir(DRIVE_PROJECT_PATH)
print(f"📂 Çalışma dizini: {os.getcwd()}")

checkpoint_files = sorted(glob.glob(f"{CHECKPOINT_PATH}/ema_*.pt"))

if checkpoint_files:
    checkpoint_file = checkpoint_files[-1]
    print(f"📂 Vector karşılaştırma için checkpoint: {checkpoint_file}")
else:
    print("⚠️ Checkpoint bulunamadı. Önce eğitim/örnekleme hücrelerini çalıştır.")
    checkpoint_file = None

if checkpoint_file:
    os.makedirs("./outputs", exist_ok=True)
    out_jsonl = f"./outputs/{MODEL_NAME}_{DATASET.lower()}_real_vs_black_vectors.jsonl"
    out_pt = f"./outputs/{MODEL_NAME}_{DATASET.lower()}_real_vs_black_vectors.pt"

    image_dir_arg = ACTIVE_IMAGE_DIR if "ACTIVE_IMAGE_DIR" in globals() else LOCAL_IMAGE_DIR
    print(f"🧭 compare dataset: {DATASET} | data_dir: {DATA_DIR} | image_dir: {image_dir_arg}")

    cmd = [
        sys.executable,
        "-m", "scripts.compare_image_black_vectors",
        "--model_path", checkpoint_file,
        "--split", "test",
        "--batch_size", str(BATCH_SIZE),
        "--max_samples", "50",
        "--data_dir", DATA_DIR,
        "--dataset", DATASET,
        "--image_dir", image_dir_arg,
        "--out_jsonl", out_jsonl,
        "--out_pt", out_pt,
    ]

    print("🚀 Komut çalıştırılıyor:")
    print(" ".join(cmd))

    result = subprocess.run(cmd, text=True, capture_output=True)
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print("[stderr]")
        print(result.stderr)

    if result.returncode == 0 and os.path.exists(out_jsonl):
        print("\n✅ Vector comparison testi tamamlandı")
        print(f"📄 JSONL: {out_jsonl}")
        print(f"🧠 PT   : {out_pt}")
        print("\n📌 İlk 3 satır:")
        with open(out_jsonl, "r", encoding="utf-8") as f:
            for idx, line in enumerate(f):
                if idx >= 3:
                    break
                print(line.rstrip())
    else:
        print(f"⚠️ Vector comparison başarısız (return code: {result.returncode}).")
        print("Logları kontrol et. Gerekirse PYTHONPATH ayarı ile tekrar deneyebilirsin.")
# Out:
# 📂 Çalışma dizini: /content/drive/MyDrive/DiffuVQA
# 📂 Vector karşılaştırma için checkpoint: /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# 🧭 compare dataset: daveKevin | data_dir: datasets | image_dir: /content/DiffuVQA/datasets
# 🚀 Komut çalıştırılıyor:
# /usr/bin/python3 -m scripts.compare_image_black_vectors --model_path /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt --split test --batch_size 2 --max_samples 50 --data_dir datasets --dataset daveKevin --image_dir /content/DiffuVQA/datasets --out_jsonl ./outputs/Bio-Bert_davekevin_real_vs_black_vectors.jsonl --out_pt ./outputs/Bio-Bert_davekevin_real_vs_black_vectors.pt
# Logging to /tmp/openai-2026-03-12-01-09-23-797278
# Loading model from: /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001/ema_0.9999_001000.pt
# Using device: cuda
# initializing from pretrained bert...
# BertConfig {
#   "add_cross_attention": false,
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "classifier_dropout": null,
#   "eos_token_id": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.0.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# save tokenizer to /content/drive/MyDrive/DiffuVQA/checkpoints/davekevin/bio-bert/btch2/lr0.0001
# ##############################
# Loading text data...
# ##############################
# Loading dataset daveKevin from datasets...
# ### Loading DaveKevin/MedVQA dataset from HuggingFace...
# ### Using samples 14881-16536 for TEST set...
# ### Found cached images in datasets/daveKevin_images/test, skipping download...
# ### Processing 1655 samples from DaveKevin/MedVQA...
# ### Processed 0/1655 samples...
# ### Processed 500/1655 samples...
# ### Processed 1000/1655 samples...
# ### Processed 1500/1655 samples...
# ### Finished processing DaveKevin/MedVQA test set
# ### Data samples...
# questions: ['What does the arrow pointing to in the image represent?', 'What is ulnar neuritis?'] answers: ['The arrow points to the ulnar nerve in the cubital tunnel, showing findings consistent with ulnar neuritis.', 'Ulnar neuritis is inflammation of the ulnar nerve, which can cause symptoms such as pain, numbness, and weakness in the hand and arm.'] images: ['test/medvqa_test_000000.png', 'test/medvqa_test_000001.png']
# Attempted image path: datasets/daveKevin_images/test/medvqa_test_000000.png
# Parent folder of attempted image path: datasets/daveKevin_images/test
# Inside parent folder (datasets/daveKevin_images/test): ['medvqa_test_000000.png', 'medvqa_test_000001.png', 'medvqa_test_000002.png', 'medvqa_test_000003.png', 'medvqa_test_000004.png', 'medvqa_test_000005.png', 'medvqa_test_000006.png', 'medvqa_test_000007.png', 'medvqa_test_000008.png', 'medvqa_test_000009.png', 'medvqa_test_000010.png', 'medvqa_test_000011.png', 'medvqa_test_000012.png', 'medvqa_test_000013.png', 'medvqa_test_000014.png', 'medvqa_test_000015.png', 'medvqa_test_000016.png', 'medvqa_test_000017.png', 'medvqa_test_000018.png', 'medvqa_test_000019.png', 'medvqa_test_000020.png', 'medvqa_test_000021.png', 'medvqa_test_000022.png', 'medvqa_test_000023.png', 'medvqa_test_000024.png', 'medvqa_test_000025.png', 'medvqa_test_000026.png', 'medvqa_test_000027.png', 'medvqa_test_000028.png', 'medvqa_test_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/test/medvqa_test_000000.png
# Attempted image path: datasets/daveKevin_images/test/medvqa_test_000001.png
# Parent folder of attempted image path: datasets/daveKevin_images/test
# Inside parent folder (datasets/daveKevin_images/test): ['medvqa_test_000000.png', 'medvqa_test_000001.png', 'medvqa_test_000002.png', 'medvqa_test_000003.png', 'medvqa_test_000004.png', 'medvqa_test_000005.png', 'medvqa_test_000006.png', 'medvqa_test_000007.png', 'medvqa_test_000008.png', 'medvqa_test_000009.png', 'medvqa_test_000010.png', 'medvqa_test_000011.png', 'medvqa_test_000012.png', 'medvqa_test_000013.png', 'medvqa_test_000014.png', 'medvqa_test_000015.png', 'medvqa_test_000016.png', 'medvqa_test_000017.png', 'medvqa_test_000018.png', 'medvqa_test_000019.png', 'medvqa_test_000020.png', 'medvqa_test_000021.png', 'medvqa_test_000022.png', 'medvqa_test_000023.png', 'medvqa_test_000024.png', 'medvqa_test_000025.png', 'medvqa_test_000026.png', 'medvqa_test_000027.png', 'medvqa_test_000028.png', 'medvqa_test_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/test/medvqa_test_000001.png
# Attempted image path: datasets/daveKevin_images/test/medvqa_test_000002.png
# Parent folder of attempted image path: datasets/daveKevin_images/test
# Inside parent folder (datasets/daveKevin_images/test): ['medvqa_test_000000.png', 'medvqa_test_000001.png', 'medvqa_test_000002.png', 'medvqa_test_000003.png', 'medvqa_test_000004.png', 'medvqa_test_000005.png', 'medvqa_test_000006.png', 'medvqa_test_000007.png', 'medvqa_test_000008.png', 'medvqa_test_000009.png', 'medvqa_test_000010.png', 'medvqa_test_000011.png', 'medvqa_test_000012.png', 'medvqa_test_000013.png', 'medvqa_test_000014.png', 'medvqa_test_000015.png', 'medvqa_test_000016.png', 'medvqa_test_000017.png', 'medvqa_test_000018.png', 'medvqa_test_000019.png', 'medvqa_test_000020.png', 'medvqa_test_000021.png', 'medvqa_test_000022.png', 'medvqa_test_000023.png', 'medvqa_test_000024.png', 'medvqa_test_000025.png', 'medvqa_test_000026.png', 'medvqa_test_000027.png', 'medvqa_test_000028.png', 'medvqa_test_000029.png']
# ### Loading image for preview: datasets/daveKevin_images/test/medvqa_test_000002.png
# ### Saved sample preview to datasets/daveKevin_test_first3_preview.png
# Figure(1500x500)
# RAM used: 3528.96 MB
# Dataset size: 1655
# Tokenized 512 / 1655 -- RAM: 3543.35 MB
# Tokenized 1024 / 1655 -- RAM: 3550.70 MB
# Tokenized 1536 / 1655 -- RAM: 3551.25 MB
# Tokenized 1655 / 1655 -- RAM: 3551.25 MB
# Finished tokenization. RAM used: 3585.21 MB
# Saved full vectors to: ./outputs/Bio-Bert_davekevin_real_vs_black_vectors.pt
# ============================================================
# Processed samples: 50
# Output JSONL: ./outputs/Bio-Bert_davekevin_real_vs_black_vectors.jsonl
# Average cosine similarity (real vs black): 0.999987
# Average L2 distance (real vs black): 0.034287
# Lower cosine / higher L2 means image content has stronger effect.
# ============================================================
#
# [stderr]
#
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/199 [00:00<00:00, 11037.64it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   1%|          | 1/199 [00:00<00:00, 3930.93it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   1%|          | 2/199 [00:00<00:00, 3496.71it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   1%|          | 2/199 [00:00<00:00, 2819.70it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   2%|▏         | 3/199 [00:00<00:00, 3331.46it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   2%|▏         | 3/199 [00:00<00:00, 2964.87it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   2%|▏         | 4/199 [00:00<00:00, 3227.63it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   2%|▏         | 4/199 [00:00<00:00, 2881.20it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   3%|▎         | 5/199 [00:00<00:00, 3104.59it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   3%|▎         | 5/199 [00:00<00:00, 2876.75it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   3%|▎         | 6/199 [00:00<00:00, 3073.13it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   3%|▎         | 6/199 [00:00<00:00, 2883.01it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   4%|▎         | 7/199 [00:00<00:00, 3023.08it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   4%|▎         | 7/199 [00:00<00:00, 2857.99it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   4%|▍         | 8/199 [00:00<00:00, 2965.22it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   4%|▍         | 8/199 [00:00<00:00, 2817.57it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   5%|▍         | 9/199 [00:00<00:00, 2936.96it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   5%|▍         | 9/199 [00:00<00:00, 2814.76it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   5%|▌         | 10/199 [00:00<00:00, 2920.21it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   5%|▌         | 10/199 [00:00<00:00, 2631.80it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:   6%|▌         | 11/199 [00:00<00:00, 2718.92it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   6%|▌         | 11/199 [00:00<00:00, 2638.23it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:   6%|▌         | 12/199 [00:00<00:00, 2735.42it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   6%|▌         | 12/199 [00:00<00:00, 2658.69it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:   7%|▋         | 13/199 [00:00<00:00, 2736.42it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   7%|▋         | 13/199 [00:00<00:00, 2657.86it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:   7%|▋         | 14/199 [00:00<00:00, 2740.99it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   7%|▋         | 14/199 [00:00<00:00, 2675.18it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:   8%|▊         | 15/199 [00:00<00:00, 2752.77it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   8%|▊         | 15/199 [00:00<00:00, 2686.02it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:   8%|▊         | 16/199 [00:00<00:00, 2752.62it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   8%|▊         | 16/199 [00:00<00:00, 2698.93it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:   9%|▊         | 17/199 [00:00<00:00, 2761.12it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   9%|▊         | 17/199 [00:00<00:00, 2709.60it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:   9%|▉         | 18/199 [00:00<00:00, 2773.50it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:   9%|▉         | 18/199 [00:00<00:00, 2708.62it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  10%|▉         | 19/199 [00:00<00:00, 2768.81it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  10%|▉         | 19/199 [00:00<00:00, 2724.41it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  10%|█         | 20/199 [00:00<00:00, 2783.49it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:  10%|█         | 20/199 [00:00<00:00, 2737.89it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:  11%|█         | 21/199 [00:00<00:00, 2795.32it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:  11%|█         | 21/199 [00:00<00:00, 2731.43it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:  11%|█         | 22/199 [00:00<00:00, 2785.40it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  11%|█         | 22/199 [00:00<00:00, 2746.35it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  12%|█▏        | 23/199 [00:00<00:00, 2793.77it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 23/199 [00:00<00:00, 2749.74it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  12%|█▏        | 24/199 [00:00<00:00, 2800.79it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:  12%|█▏        | 24/199 [00:00<00:00, 2763.80it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:  13%|█▎        | 25/199 [00:00<00:00, 2818.68it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:  13%|█▎        | 25/199 [00:00<00:00, 2785.95it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:  13%|█▎        | 26/199 [00:00<00:00, 2840.78it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:  13%|█▎        | 26/199 [00:00<00:00, 2809.60it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:  14%|█▎        | 27/199 [00:00<00:00, 2851.76it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:  14%|█▎        | 27/199 [00:00<00:00, 2810.78it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:  14%|█▍        | 28/199 [00:00<00:00, 2848.15it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:  14%|█▍        | 28/199 [00:00<00:00, 2810.19it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:  15%|█▍        | 29/199 [00:00<00:00, 2849.32it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:  15%|█▍        | 29/199 [00:00<00:00, 2811.98it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:  15%|█▌        | 30/199 [00:00<00:00, 2855.08it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:  15%|█▌        | 30/199 [00:00<00:00, 2819.45it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:  16%|█▌        | 31/199 [00:00<00:00, 2862.06it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:  16%|█▌        | 31/199 [00:00<00:00, 2832.57it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:  16%|█▌        | 32/199 [00:00<00:00, 2874.96it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:  16%|█▌        | 32/199 [00:00<00:00, 2845.77it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:  17%|█▋        | 33/199 [00:00<00:00, 2885.39it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:  17%|█▋        | 33/199 [00:00<00:00, 2852.92it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:  17%|█▋        | 34/199 [00:00<00:00, 2891.68it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  17%|█▋        | 34/199 [00:00<00:00, 2864.21it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  18%|█▊        | 35/199 [00:00<00:00, 2904.76it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  18%|█▊        | 35/199 [00:00<00:00, 2878.22it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  18%|█▊        | 36/199 [00:00<00:00, 2915.35it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:  18%|█▊        | 36/199 [00:00<00:00, 2889.14it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:  19%|█▊        | 37/199 [00:00<00:00, 2923.30it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:  19%|█▊        | 37/199 [00:00<00:00, 2897.65it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:  19%|█▉        | 38/199 [00:00<00:00, 2934.86it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:  19%|█▉        | 38/199 [00:00<00:00, 2907.88it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:  20%|█▉        | 39/199 [00:00<00:00, 2931.45it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:  20%|█▉        | 39/199 [00:00<00:00, 2902.48it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:  20%|██        | 40/199 [00:00<00:00, 2926.38it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:  20%|██        | 40/199 [00:00<00:00, 2900.02it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:  21%|██        | 41/199 [00:00<00:00, 2932.18it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:  21%|██        | 41/199 [00:00<00:00, 2907.98it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:  21%|██        | 42/199 [00:00<00:00, 2935.62it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:  21%|██        | 42/199 [00:00<00:00, 2912.95it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:  22%|██▏       | 43/199 [00:00<00:00, 2944.19it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  22%|██▏       | 43/199 [00:00<00:00, 2920.73it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  22%|██▏       | 44/199 [00:00<00:00, 2947.88it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  22%|██▏       | 44/199 [00:00<00:00, 2922.86it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  23%|██▎       | 45/199 [00:00<00:00, 2948.48it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  23%|██▎       | 45/199 [00:00<00:00, 2923.90it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  23%|██▎       | 46/199 [00:00<00:00, 2946.88it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  23%|██▎       | 46/199 [00:00<00:00, 2918.79it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  24%|██▎       | 47/199 [00:00<00:00, 2941.13it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  24%|██▎       | 47/199 [00:00<00:00, 2919.57it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  24%|██▍       | 48/199 [00:00<00:00, 2942.12it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  24%|██▍       | 48/199 [00:00<00:00, 2919.22it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  25%|██▍       | 49/199 [00:00<00:00, 2940.68it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  25%|██▍       | 49/199 [00:00<00:00, 2919.66it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  25%|██▌       | 50/199 [00:00<00:00, 2940.73it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  25%|██▌       | 50/199 [00:00<00:00, 2917.37it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  26%|██▌       | 51/199 [00:00<00:00, 2938.68it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  26%|██▌       | 51/199 [00:00<00:00, 2918.79it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  26%|██▌       | 52/199 [00:00<00:00, 2940.43it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  26%|██▌       | 52/199 [00:00<00:00, 2921.33it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  27%|██▋       | 53/199 [00:00<00:00, 2946.41it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  27%|██▋       | 53/199 [00:00<00:00, 2928.37it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  27%|██▋       | 54/199 [00:00<00:00, 2953.97it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  27%|██▋       | 54/199 [00:00<00:00, 2930.84it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  28%|██▊       | 55/199 [00:00<00:00, 2946.91it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  28%|██▊       | 55/199 [00:00<00:00, 2926.46it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  28%|██▊       | 56/199 [00:00<00:00, 2946.18it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  28%|██▊       | 56/199 [00:00<00:00, 2927.09it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  29%|██▊       | 57/199 [00:00<00:00, 2940.80it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  29%|██▊       | 57/199 [00:00<00:00, 2919.54it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  29%|██▉       | 58/199 [00:00<00:00, 2933.01it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  29%|██▉       | 58/199 [00:00<00:00, 2914.60it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  30%|██▉       | 59/199 [00:00<00:00, 2933.29it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  30%|██▉       | 59/199 [00:00<00:00, 2915.32it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  30%|███       | 60/199 [00:00<00:00, 2931.88it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  30%|███       | 60/199 [00:00<00:00, 2911.63it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  31%|███       | 61/199 [00:00<00:00, 2928.65it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  31%|███       | 61/199 [00:00<00:00, 2911.25it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  31%|███       | 62/199 [00:00<00:00, 2925.66it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  31%|███       | 62/199 [00:00<00:00, 2904.84it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  32%|███▏      | 63/199 [00:00<00:00, 2917.60it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  32%|███▏      | 63/199 [00:00<00:00, 2899.67it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  32%|███▏      | 64/199 [00:00<00:00, 2916.26it/s, Materializing param=encoder.layer.3.intermediate.dense.bias]
# Loading weights:  32%|███▏      | 64/199 [00:00<00:00, 2896.53it/s, Materializing param=encoder.layer.3.intermediate.dense.bias]
# Loading weights:  33%|███▎      | 65/199 [00:00<00:00, 2910.91it/s, Materializing param=encoder.layer.3.intermediate.dense.weight]
# Loading weights:  33%|███▎      | 65/199 [00:00<00:00, 2895.27it/s, Materializing param=encoder.layer.3.intermediate.dense.weight]
# Loading weights:  33%|███▎      | 66/199 [00:00<00:00, 2911.95it/s, Materializing param=encoder.layer.3.output.LayerNorm.bias]
# Loading weights:  33%|███▎      | 66/199 [00:00<00:00, 2896.32it/s, Materializing param=encoder.layer.3.output.LayerNorm.bias]
# Loading weights:  34%|███▎      | 67/199 [00:00<00:00, 2912.83it/s, Materializing param=encoder.layer.3.output.LayerNorm.weight]
# Loading weights:  34%|███▎      | 67/199 [00:00<00:00, 2895.51it/s, Materializing param=encoder.layer.3.output.LayerNorm.weight]
# Loading weights:  34%|███▍      | 68/199 [00:00<00:00, 2911.88it/s, Materializing param=encoder.layer.3.output.dense.bias]
# Loading weights:  34%|███▍      | 68/199 [00:00<00:00, 2898.09it/s, Materializing param=encoder.layer.3.output.dense.bias]
# Loading weights:  35%|███▍      | 69/199 [00:00<00:00, 2914.82it/s, Materializing param=encoder.layer.3.output.dense.weight]
# Loading weights:  35%|███▍      | 69/199 [00:00<00:00, 2899.29it/s, Materializing param=encoder.layer.3.output.dense.weight]
# Loading weights:  35%|███▌      | 70/199 [00:00<00:00, 2918.21it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.bias]
# Loading weights:  35%|███▌      | 70/199 [00:00<00:00, 2903.72it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.bias]
# Loading weights:  36%|███▌      | 71/199 [00:00<00:00, 2920.97it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.weight]
# Loading weights:  36%|███▌      | 71/199 [00:00<00:00, 2906.49it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.weight]
# Loading weights:  36%|███▌      | 72/199 [00:00<00:00, 2921.67it/s, Materializing param=encoder.layer.4.attention.output.dense.bias]
# Loading weights:  36%|███▌      | 72/199 [00:00<00:00, 2906.88it/s, Materializing param=encoder.layer.4.attention.output.dense.bias]
# Loading weights:  37%|███▋      | 73/199 [00:00<00:00, 2924.12it/s, Materializing param=encoder.layer.4.attention.output.dense.weight]
# Loading weights:  37%|███▋      | 73/199 [00:00<00:00, 2910.27it/s, Materializing param=encoder.layer.4.attention.output.dense.weight]
# Loading weights:  37%|███▋      | 74/199 [00:00<00:00, 2928.07it/s, Materializing param=encoder.layer.4.attention.self.key.bias]
# Loading weights:  37%|███▋      | 74/199 [00:00<00:00, 2913.67it/s, Materializing param=encoder.layer.4.attention.self.key.bias]
# Loading weights:  38%|███▊      | 75/199 [00:00<00:00, 2927.65it/s, Materializing param=encoder.layer.4.attention.self.key.weight]
# Loading weights:  38%|███▊      | 75/199 [00:00<00:00, 2913.71it/s, Materializing param=encoder.layer.4.attention.self.key.weight]
# Loading weights:  38%|███▊      | 76/199 [00:00<00:00, 2930.79it/s, Materializing param=encoder.layer.4.attention.self.query.bias]
# Loading weights:  38%|███▊      | 76/199 [00:00<00:00, 2917.62it/s, Materializing param=encoder.layer.4.attention.self.query.bias]
# Loading weights:  39%|███▊      | 77/199 [00:00<00:00, 2934.12it/s, Materializing param=encoder.layer.4.attention.self.query.weight]
# Loading weights:  39%|███▊      | 77/199 [00:00<00:00, 2919.90it/s, Materializing param=encoder.layer.4.attention.self.query.weight]
# Loading weights:  39%|███▉      | 78/199 [00:00<00:00, 2934.55it/s, Materializing param=encoder.layer.4.attention.self.value.bias]
# Loading weights:  39%|███▉      | 78/199 [00:00<00:00, 2920.85it/s, Materializing param=encoder.layer.4.attention.self.value.bias]
# Loading weights:  40%|███▉      | 79/199 [00:00<00:00, 2936.54it/s, Materializing param=encoder.layer.4.attention.self.value.weight]
# Loading weights:  40%|███▉      | 79/199 [00:00<00:00, 2923.58it/s, Materializing param=encoder.layer.4.attention.self.value.weight]
# Loading weights:  40%|████      | 80/199 [00:00<00:00, 2940.04it/s, Materializing param=encoder.layer.4.intermediate.dense.bias]
# Loading weights:  40%|████      | 80/199 [00:00<00:00, 2926.45it/s, Materializing param=encoder.layer.4.intermediate.dense.bias]
# Loading weights:  41%|████      | 81/199 [00:00<00:00, 2941.10it/s, Materializing param=encoder.layer.4.intermediate.dense.weight]
# Loading weights:  41%|████      | 81/199 [00:00<00:00, 2927.85it/s, Materializing param=encoder.layer.4.intermediate.dense.weight]
# Loading weights:  41%|████      | 82/199 [00:00<00:00, 2943.40it/s, Materializing param=encoder.layer.4.output.LayerNorm.bias]
# Loading weights:  41%|████      | 82/199 [00:00<00:00, 2931.18it/s, Materializing param=encoder.layer.4.output.LayerNorm.bias]
# Loading weights:  42%|████▏     | 83/199 [00:00<00:00, 2947.28it/s, Materializing param=encoder.layer.4.output.LayerNorm.weight]
# Loading weights:  42%|████▏     | 83/199 [00:00<00:00, 2935.08it/s, Materializing param=encoder.layer.4.output.LayerNorm.weight]
# Loading weights:  42%|████▏     | 84/199 [00:00<00:00, 2949.06it/s, Materializing param=encoder.layer.4.output.dense.bias]
# Loading weights:  42%|████▏     | 84/199 [00:00<00:00, 2935.23it/s, Materializing param=encoder.layer.4.output.dense.bias]
# Loading weights:  43%|████▎     | 85/199 [00:00<00:00, 2950.26it/s, Materializing param=encoder.layer.4.output.dense.weight]
# Loading weights:  43%|████▎     | 85/199 [00:00<00:00, 2938.28it/s, Materializing param=encoder.layer.4.output.dense.weight]
# Loading weights:  43%|████▎     | 86/199 [00:00<00:00, 2954.12it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.bias]
# Loading weights:  43%|████▎     | 86/199 [00:00<00:00, 2942.34it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.bias]
# Loading weights:  44%|████▎     | 87/199 [00:00<00:00, 2954.62it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.weight]
# Loading weights:  44%|████▎     | 87/199 [00:00<00:00, 2941.12it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.weight]
# Loading weights:  44%|████▍     | 88/199 [00:00<00:00, 2956.48it/s, Materializing param=encoder.layer.5.attention.output.dense.bias]
# Loading weights:  44%|████▍     | 88/199 [00:00<00:00, 2945.93it/s, Materializing param=encoder.layer.5.attention.output.dense.bias]
# Loading weights:  45%|████▍     | 89/199 [00:00<00:00, 2962.76it/s, Materializing param=encoder.layer.5.attention.output.dense.weight]
# Loading weights:  45%|████▍     | 89/199 [00:00<00:00, 2952.36it/s, Materializing param=encoder.layer.5.attention.output.dense.weight]
# Loading weights:  45%|████▌     | 90/199 [00:00<00:00, 2968.16it/s, Materializing param=encoder.layer.5.attention.self.key.bias]
# Loading weights:  45%|████▌     | 90/199 [00:00<00:00, 2957.79it/s, Materializing param=encoder.layer.5.attention.self.key.bias]
# Loading weights:  46%|████▌     | 91/199 [00:00<00:00, 2971.95it/s, Materializing param=encoder.layer.5.attention.self.key.weight]
# Loading weights:  46%|████▌     | 91/199 [00:00<00:00, 2959.94it/s, Materializing param=encoder.layer.5.attention.self.key.weight]
# Loading weights:  46%|████▌     | 92/199 [00:00<00:00, 2973.51it/s, Materializing param=encoder.layer.5.attention.self.query.bias]
# Loading weights:  46%|████▌     | 92/199 [00:00<00:00, 2962.01it/s, Materializing param=encoder.layer.5.attention.self.query.bias]
# Loading weights:  47%|████▋     | 93/199 [00:00<00:00, 2976.02it/s, Materializing param=encoder.layer.5.attention.self.query.weight]
# Loading weights:  47%|████▋     | 93/199 [00:00<00:00, 2963.81it/s, Materializing param=encoder.layer.5.attention.self.query.weight]
# Loading weights:  47%|████▋     | 94/199 [00:00<00:00, 2975.99it/s, Materializing param=encoder.layer.5.attention.self.value.bias]
# Loading weights:  47%|████▋     | 94/199 [00:00<00:00, 2964.31it/s, Materializing param=encoder.layer.5.attention.self.value.bias]
# Loading weights:  48%|████▊     | 95/199 [00:00<00:00, 2977.57it/s, Materializing param=encoder.layer.5.attention.self.value.weight]
# Loading weights:  48%|████▊     | 95/199 [00:00<00:00, 2966.36it/s, Materializing param=encoder.layer.5.attention.self.value.weight]
# Loading weights:  48%|████▊     | 96/199 [00:00<00:00, 2979.83it/s, Materializing param=encoder.layer.5.intermediate.dense.bias]
# Loading weights:  48%|████▊     | 96/199 [00:00<00:00, 2968.15it/s, Materializing param=encoder.layer.5.intermediate.dense.bias]
# Loading weights:  49%|████▊     | 97/199 [00:00<00:00, 2980.35it/s, Materializing param=encoder.layer.5.intermediate.dense.weight]
# Loading weights:  49%|████▊     | 97/199 [00:00<00:00, 2969.08it/s, Materializing param=encoder.layer.5.intermediate.dense.weight]
# Loading weights:  49%|████▉     | 98/199 [00:00<00:00, 2979.32it/s, Materializing param=encoder.layer.5.output.LayerNorm.bias]
# Loading weights:  49%|████▉     | 98/199 [00:00<00:00, 2963.68it/s, Materializing param=encoder.layer.5.output.LayerNorm.bias]
# Loading weights:  50%|████▉     | 99/199 [00:00<00:00, 2967.07it/s, Materializing param=encoder.layer.5.output.LayerNorm.weight]
# Loading weights:  50%|████▉     | 99/199 [00:00<00:00, 2950.63it/s, Materializing param=encoder.layer.5.output.LayerNorm.weight]
# Loading weights:  50%|█████     | 100/199 [00:00<00:00, 2958.34it/s, Materializing param=encoder.layer.5.output.dense.bias]
# Loading weights:  50%|█████     | 100/199 [00:00<00:00, 2947.45it/s, Materializing param=encoder.layer.5.output.dense.bias]
# Loading weights:  51%|█████     | 101/199 [00:00<00:00, 2960.42it/s, Materializing param=encoder.layer.5.output.dense.weight]
# Loading weights:  51%|█████     | 101/199 [00:00<00:00, 2950.30it/s, Materializing param=encoder.layer.5.output.dense.weight]
# Loading weights:  51%|█████▏    | 102/199 [00:00<00:00, 2961.96it/s, Materializing param=encoder.layer.6.attention.output.LayerNorm.bias]
# Loading weights:  51%|█████▏    | 102/199 [00:00<00:00, 2950.23it/s, Materializing param=encoder.layer.6.attention.output.LayerNorm.bias]
# Loading weights:  52%|█████▏    | 103/199 [00:00<00:00, 2962.47it/s, Materializing param=encoder.layer.6.attention.output.LayerNorm.weight]
# Loading weights:  52%|█████▏    | 103/199 [00:00<00:00, 2953.11it/s, Materializing param=encoder.layer.6.attention.output.LayerNorm.weight]
# Loading weights:  52%|█████▏    | 104/199 [00:00<00:00, 2968.04it/s, Materializing param=encoder.layer.6.attention.output.dense.bias]
# Loading weights:  52%|█████▏    | 104/199 [00:00<00:00, 2959.61it/s, Materializing param=encoder.layer.6.attention.output.dense.bias]
# Loading weights:  53%|█████▎    | 105/199 [00:00<00:00, 2974.08it/s, Materializing param=encoder.layer.6.attention.output.dense.weight]
# Loading weights:  53%|█████▎    | 105/199 [00:00<00:00, 2965.45it/s, Materializing param=encoder.layer.6.attention.output.dense.weight]
# Loading weights:  53%|█████▎    | 106/199 [00:00<00:00, 2973.91it/s, Materializing param=encoder.layer.6.attention.self.key.bias]
# Loading weights:  53%|█████▎    | 106/199 [00:00<00:00, 2962.41it/s, Materializing param=encoder.layer.6.attention.self.key.bias]
# Loading weights:  54%|█████▍    | 107/199 [00:00<00:00, 2971.24it/s, Materializing param=encoder.layer.6.attention.self.key.weight]
# Loading weights:  54%|█████▍    | 107/199 [00:00<00:00, 2959.93it/s, Materializing param=encoder.layer.6.attention.self.key.weight]
# Loading weights:  54%|█████▍    | 108/199 [00:00<00:00, 2967.10it/s, Materializing param=encoder.layer.6.attention.self.query.bias]
# Loading weights:  54%|█████▍    | 108/199 [00:00<00:00, 2955.05it/s, Materializing param=encoder.layer.6.attention.self.query.bias]
# Loading weights:  55%|█████▍    | 109/199 [00:00<00:00, 2962.94it/s, Materializing param=encoder.layer.6.attention.self.query.weight]
# Loading weights:  55%|█████▍    | 109/199 [00:00<00:00, 2951.58it/s, Materializing param=encoder.layer.6.attention.self.query.weight]
# Loading weights:  55%|█████▌    | 110/199 [00:00<00:00, 2960.10it/s, Materializing param=encoder.layer.6.attention.self.value.bias]
# Loading weights:  55%|█████▌    | 110/199 [00:00<00:00, 2948.20it/s, Materializing param=encoder.layer.6.attention.self.value.bias]
# Loading weights:  56%|█████▌    | 111/199 [00:00<00:00, 2954.56it/s, Materializing param=encoder.layer.6.attention.self.value.weight]
# Loading weights:  56%|█████▌    | 111/199 [00:00<00:00, 2943.58it/s, Materializing param=encoder.layer.6.attention.self.value.weight]
# Loading weights:  56%|█████▋    | 112/199 [00:00<00:00, 2952.68it/s, Materializing param=encoder.layer.6.intermediate.dense.bias]
# Loading weights:  56%|█████▋    | 112/199 [00:00<00:00, 2942.30it/s, Materializing param=encoder.layer.6.intermediate.dense.bias]
# Loading weights:  57%|█████▋    | 113/199 [00:00<00:00, 2950.77it/s, Materializing param=encoder.layer.6.intermediate.dense.weight]
# Loading weights:  57%|█████▋    | 113/199 [00:00<00:00, 2940.18it/s, Materializing param=encoder.layer.6.intermediate.dense.weight]
# Loading weights:  57%|█████▋    | 114/199 [00:00<00:00, 2947.20it/s, Materializing param=encoder.layer.6.output.LayerNorm.bias]
# Loading weights:  57%|█████▋    | 114/199 [00:00<00:00, 2936.68it/s, Materializing param=encoder.layer.6.output.LayerNorm.bias]
# Loading weights:  58%|█████▊    | 115/199 [00:00<00:00, 2946.03it/s, Materializing param=encoder.layer.6.output.LayerNorm.weight]
# Loading weights:  58%|█████▊    | 115/199 [00:00<00:00, 2935.86it/s, Materializing param=encoder.layer.6.output.LayerNorm.weight]
# Loading weights:  58%|█████▊    | 116/199 [00:00<00:00, 2944.51it/s, Materializing param=encoder.layer.6.output.dense.bias]
# Loading weights:  58%|█████▊    | 116/199 [00:00<00:00, 2911.93it/s, Materializing param=encoder.layer.6.output.dense.bias]
# Loading weights:  59%|█████▉    | 117/199 [00:00<00:00, 2919.94it/s, Materializing param=encoder.layer.6.output.dense.weight]
# Loading weights:  59%|█████▉    | 117/199 [00:00<00:00, 2910.79it/s, Materializing param=encoder.layer.6.output.dense.weight]
# Loading weights:  59%|█████▉    | 118/199 [00:00<00:00, 2919.81it/s, Materializing param=encoder.layer.7.attention.output.LayerNorm.bias]
# Loading weights:  59%|█████▉    | 118/199 [00:00<00:00, 2909.34it/s, Materializing param=encoder.layer.7.attention.output.LayerNorm.bias]
# Loading weights:  60%|█████▉    | 119/199 [00:00<00:00, 2916.98it/s, Materializing param=encoder.layer.7.attention.output.LayerNorm.weight]
# Loading weights:  60%|█████▉    | 119/199 [00:00<00:00, 2906.79it/s, Materializing param=encoder.layer.7.attention.output.LayerNorm.weight]
# Loading weights:  60%|██████    | 120/199 [00:00<00:00, 2914.85it/s, Materializing param=encoder.layer.7.attention.output.dense.bias]
# Loading weights:  60%|██████    | 120/199 [00:00<00:00, 2904.58it/s, Materializing param=encoder.layer.7.attention.output.dense.bias]
# Loading weights:  61%|██████    | 121/199 [00:00<00:00, 2910.16it/s, Materializing param=encoder.layer.7.attention.output.dense.weight]
# Loading weights:  61%|██████    | 121/199 [00:00<00:00, 2899.80it/s, Materializing param=encoder.layer.7.attention.output.dense.weight]
# Loading weights:  61%|██████▏   | 122/199 [00:00<00:00, 2906.74it/s, Materializing param=encoder.layer.7.attention.self.key.bias]
# Loading weights:  61%|██████▏   | 122/199 [00:00<00:00, 2896.68it/s, Materializing param=encoder.layer.7.attention.self.key.bias]
# Loading weights:  62%|██████▏   | 123/199 [00:00<00:00, 2904.07it/s, Materializing param=encoder.layer.7.attention.self.key.weight]
# Loading weights:  62%|██████▏   | 123/199 [00:00<00:00, 2895.22it/s, Materializing param=encoder.layer.7.attention.self.key.weight]
# Loading weights:  62%|██████▏   | 124/199 [00:00<00:00, 2902.68it/s, Materializing param=encoder.layer.7.attention.self.query.bias]
# Loading weights:  62%|██████▏   | 124/199 [00:00<00:00, 2893.33it/s, Materializing param=encoder.layer.7.attention.self.query.bias]
# Loading weights:  63%|██████▎   | 125/199 [00:00<00:00, 2900.87it/s, Materializing param=encoder.layer.7.attention.self.query.weight]
# Loading weights:  63%|██████▎   | 125/199 [00:00<00:00, 2891.47it/s, Materializing param=encoder.layer.7.attention.self.query.weight]
# Loading weights:  63%|██████▎   | 126/199 [00:00<00:00, 2899.35it/s, Materializing param=encoder.layer.7.attention.self.value.bias]
# Loading weights:  63%|██████▎   | 126/199 [00:00<00:00, 2889.19it/s, Materializing param=encoder.layer.7.attention.self.value.bias]
# Loading weights:  64%|██████▍   | 127/199 [00:00<00:00, 2896.02it/s, Materializing param=encoder.layer.7.attention.self.value.weight]
# Loading weights:  64%|██████▍   | 127/199 [00:00<00:00, 2886.82it/s, Materializing param=encoder.layer.7.attention.self.value.weight]
# Loading weights:  64%|██████▍   | 128/199 [00:00<00:00, 2894.53it/s, Materializing param=encoder.layer.7.intermediate.dense.bias]
# Loading weights:  64%|██████▍   | 128/199 [00:00<00:00, 2885.02it/s, Materializing param=encoder.layer.7.intermediate.dense.bias]
# Loading weights:  65%|██████▍   | 129/199 [00:00<00:00, 2892.76it/s, Materializing param=encoder.layer.7.intermediate.dense.weight]
# Loading weights:  65%|██████▍   | 129/199 [00:00<00:00, 2883.67it/s, Materializing param=encoder.layer.7.intermediate.dense.weight]
# Loading weights:  65%|██████▌   | 130/199 [00:00<00:00, 2891.21it/s, Materializing param=encoder.layer.7.output.LayerNorm.bias]
# Loading weights:  65%|██████▌   | 130/199 [00:00<00:00, 2882.42it/s, Materializing param=encoder.layer.7.output.LayerNorm.bias]
# Loading weights:  66%|██████▌   | 131/199 [00:00<00:00, 2889.25it/s, Materializing param=encoder.layer.7.output.LayerNorm.weight]
# Loading weights:  66%|██████▌   | 131/199 [00:00<00:00, 2880.43it/s, Materializing param=encoder.layer.7.output.LayerNorm.weight]
# Loading weights:  66%|██████▋   | 132/199 [00:00<00:00, 2887.00it/s, Materializing param=encoder.layer.7.output.dense.bias]
# Loading weights:  66%|██████▋   | 132/199 [00:00<00:00, 2878.59it/s, Materializing param=encoder.layer.7.output.dense.bias]
# Loading weights:  67%|██████▋   | 133/199 [00:00<00:00, 2886.40it/s, Materializing param=encoder.layer.7.output.dense.weight]
# Loading weights:  67%|██████▋   | 133/199 [00:00<00:00, 2878.53it/s, Materializing param=encoder.layer.7.output.dense.weight]
# Loading weights:  67%|██████▋   | 134/199 [00:00<00:00, 2886.46it/s, Materializing param=encoder.layer.8.attention.output.LayerNorm.bias]
# Loading weights:  67%|██████▋   | 134/199 [00:00<00:00, 2877.13it/s, Materializing param=encoder.layer.8.attention.output.LayerNorm.bias]
# Loading weights:  68%|██████▊   | 135/199 [00:00<00:00, 2883.78it/s, Materializing param=encoder.layer.8.attention.output.LayerNorm.weight]
# Loading weights:  68%|██████▊   | 135/199 [00:00<00:00, 2875.36it/s, Materializing param=encoder.layer.8.attention.output.LayerNorm.weight]
# Loading weights:  68%|██████▊   | 136/199 [00:00<00:00, 2881.81it/s, Materializing param=encoder.layer.8.attention.output.dense.bias]
# Loading weights:  68%|██████▊   | 136/199 [00:00<00:00, 2872.52it/s, Materializing param=encoder.layer.8.attention.output.dense.bias]
# Loading weights:  69%|██████▉   | 137/199 [00:00<00:00, 2877.79it/s, Materializing param=encoder.layer.8.attention.output.dense.weight]
# Loading weights:  69%|██████▉   | 137/199 [00:00<00:00, 2869.10it/s, Materializing param=encoder.layer.8.attention.output.dense.weight]
# Loading weights:  69%|██████▉   | 138/199 [00:00<00:00, 2875.79it/s, Materializing param=encoder.layer.8.attention.self.key.bias]
# Loading weights:  69%|██████▉   | 138/199 [00:00<00:00, 2866.99it/s, Materializing param=encoder.layer.8.attention.self.key.bias]
# Loading weights:  70%|██████▉   | 139/199 [00:00<00:00, 2873.31it/s, Materializing param=encoder.layer.8.attention.self.key.weight]
# Loading weights:  70%|██████▉   | 139/199 [00:00<00:00, 2865.34it/s, Materializing param=encoder.layer.8.attention.self.key.weight]
# Loading weights:  70%|███████   | 140/199 [00:00<00:00, 2854.74it/s, Materializing param=encoder.layer.8.attention.self.query.bias]
# Loading weights:  70%|███████   | 140/199 [00:00<00:00, 2846.02it/s, Materializing param=encoder.layer.8.attention.self.query.bias]
# Loading weights:  71%|███████   | 141/199 [00:00<00:00, 2850.46it/s, Materializing param=encoder.layer.8.attention.self.query.weight]
# Loading weights:  71%|███████   | 141/199 [00:00<00:00, 2841.11it/s, Materializing param=encoder.layer.8.attention.self.query.weight]
# Loading weights:  71%|███████▏  | 142/199 [00:00<00:00, 2847.92it/s, Materializing param=encoder.layer.8.attention.self.value.bias]
# Loading weights:  71%|███████▏  | 142/199 [00:00<00:00, 2840.38it/s, Materializing param=encoder.layer.8.attention.self.value.bias]
# Loading weights:  72%|███████▏  | 143/199 [00:00<00:00, 2848.80it/s, Materializing param=encoder.layer.8.attention.self.value.weight]
# Loading weights:  72%|███████▏  | 143/199 [00:00<00:00, 2840.93it/s, Materializing param=encoder.layer.8.attention.self.value.weight]
# Loading weights:  72%|███████▏  | 144/199 [00:00<00:00, 2847.66it/s, Materializing param=encoder.layer.8.intermediate.dense.bias]
# Loading weights:  72%|███████▏  | 144/199 [00:00<00:00, 2839.36it/s, Materializing param=encoder.layer.8.intermediate.dense.bias]
# Loading weights:  73%|███████▎  | 145/199 [00:00<00:00, 2846.07it/s, Materializing param=encoder.layer.8.intermediate.dense.weight]
# Loading weights:  73%|███████▎  | 145/199 [00:00<00:00, 2838.12it/s, Materializing param=encoder.layer.8.intermediate.dense.weight]
# Loading weights:  73%|███████▎  | 146/199 [00:00<00:00, 2843.99it/s, Materializing param=encoder.layer.8.output.LayerNorm.bias]
# Loading weights:  73%|███████▎  | 146/199 [00:00<00:00, 2836.47it/s, Materializing param=encoder.layer.8.output.LayerNorm.bias]
# Loading weights:  74%|███████▍  | 147/199 [00:00<00:00, 2842.27it/s, Materializing param=encoder.layer.8.output.LayerNorm.weight]
# Loading weights:  74%|███████▍  | 147/199 [00:00<00:00, 2834.74it/s, Materializing param=encoder.layer.8.output.LayerNorm.weight]
# Loading weights:  74%|███████▍  | 148/199 [00:00<00:00, 2842.16it/s, Materializing param=encoder.layer.8.output.dense.bias]
# Loading weights:  74%|███████▍  | 148/199 [00:00<00:00, 2835.36it/s, Materializing param=encoder.layer.8.output.dense.bias]
# Loading weights:  75%|███████▍  | 149/199 [00:00<00:00, 2843.40it/s, Materializing param=encoder.layer.8.output.dense.weight]
# Loading weights:  75%|███████▍  | 149/199 [00:00<00:00, 2837.10it/s, Materializing param=encoder.layer.8.output.dense.weight]
# Loading weights:  75%|███████▌  | 150/199 [00:00<00:00, 2844.57it/s, Materializing param=encoder.layer.9.attention.output.LayerNorm.bias]
# Loading weights:  75%|███████▌  | 150/199 [00:00<00:00, 2838.68it/s, Materializing param=encoder.layer.9.attention.output.LayerNorm.bias]
# Loading weights:  76%|███████▌  | 151/199 [00:00<00:00, 2848.33it/s, Materializing param=encoder.layer.9.attention.output.LayerNorm.weight]
# Loading weights:  76%|███████▌  | 151/199 [00:00<00:00, 2842.82it/s, Materializing param=encoder.layer.9.attention.output.LayerNorm.weight]
# Loading weights:  76%|███████▋  | 152/199 [00:00<00:00, 2852.77it/s, Materializing param=encoder.layer.9.attention.output.dense.bias]
# Loading weights:  76%|███████▋  | 152/199 [00:00<00:00, 2845.63it/s, Materializing param=encoder.layer.9.attention.output.dense.bias]
# Loading weights:  77%|███████▋  | 153/199 [00:00<00:00, 2852.70it/s, Materializing param=encoder.layer.9.attention.output.dense.weight]
# Loading weights:  77%|███████▋  | 153/199 [00:00<00:00, 2846.65it/s, Materializing param=encoder.layer.9.attention.output.dense.weight]
# Loading weights:  77%|███████▋  | 154/199 [00:00<00:00, 2856.25it/s, Materializing param=encoder.layer.9.attention.self.key.bias]
# Loading weights:  77%|███████▋  | 154/199 [00:00<00:00, 2851.03it/s, Materializing param=encoder.layer.9.attention.self.key.bias]
# Loading weights:  78%|███████▊  | 155/199 [00:00<00:00, 2861.00it/s, Materializing param=encoder.layer.9.attention.self.key.weight]
# Loading weights:  78%|███████▊  | 155/199 [00:00<00:00, 2855.90it/s, Materializing param=encoder.layer.9.attention.self.key.weight]
# Loading weights:  78%|███████▊  | 156/199 [00:00<00:00, 2865.06it/s, Materializing param=encoder.layer.9.attention.self.query.bias]
# Loading weights:  78%|███████▊  | 156/199 [00:00<00:00, 2858.65it/s, Materializing param=encoder.layer.9.attention.self.query.bias]
# Loading weights:  79%|███████▉  | 157/199 [00:00<00:00, 2866.25it/s, Materializing param=encoder.layer.9.attention.self.query.weight]
# Loading weights:  79%|███████▉  | 157/199 [00:00<00:00, 2860.11it/s, Materializing param=encoder.layer.9.attention.self.query.weight]
# Loading weights:  79%|███████▉  | 158/199 [00:00<00:00, 2868.19it/s, Materializing param=encoder.layer.9.attention.self.value.bias]
# Loading weights:  79%|███████▉  | 158/199 [00:00<00:00, 2862.30it/s, Materializing param=encoder.layer.9.attention.self.value.bias]
# Loading weights:  80%|███████▉  | 159/199 [00:00<00:00, 2869.98it/s, Materializing param=encoder.layer.9.attention.self.value.weight]
# Loading weights:  80%|███████▉  | 159/199 [00:00<00:00, 2864.08it/s, Materializing param=encoder.layer.9.attention.self.value.weight]
# Loading weights:  80%|████████  | 160/199 [00:00<00:00, 2870.92it/s, Materializing param=encoder.layer.9.intermediate.dense.bias]
# Loading weights:  80%|████████  | 160/199 [00:00<00:00, 2864.93it/s, Materializing param=encoder.layer.9.intermediate.dense.bias]
# Loading weights:  81%|████████  | 161/199 [00:00<00:00, 2873.18it/s, Materializing param=encoder.layer.9.intermediate.dense.weight]
# Loading weights:  81%|████████  | 161/199 [00:00<00:00, 2867.33it/s, Materializing param=encoder.layer.9.intermediate.dense.weight]
# Loading weights:  81%|████████▏ | 162/199 [00:00<00:00, 2875.07it/s, Materializing param=encoder.layer.9.output.LayerNorm.bias]
# Loading weights:  81%|████████▏ | 162/199 [00:00<00:00, 2869.23it/s, Materializing param=encoder.layer.9.output.LayerNorm.bias]
# Loading weights:  82%|████████▏ | 163/199 [00:00<00:00, 2876.26it/s, Materializing param=encoder.layer.9.output.LayerNorm.weight]
# Loading weights:  82%|████████▏ | 163/199 [00:00<00:00, 2870.28it/s, Materializing param=encoder.layer.9.output.LayerNorm.weight]
# Loading weights:  82%|████████▏ | 164/199 [00:00<00:00, 2878.49it/s, Materializing param=encoder.layer.9.output.dense.bias]
# Loading weights:  82%|████████▏ | 164/199 [00:00<00:00, 2872.69it/s, Materializing param=encoder.layer.9.output.dense.bias]
# Loading weights:  83%|████████▎ | 165/199 [00:00<00:00, 2881.10it/s, Materializing param=encoder.layer.9.output.dense.weight]
# Loading weights:  83%|████████▎ | 165/199 [00:00<00:00, 2874.96it/s, Materializing param=encoder.layer.9.output.dense.weight]
# Loading weights:  83%|████████▎ | 166/199 [00:00<00:00, 2882.31it/s, Materializing param=encoder.layer.10.attention.output.LayerNorm.bias]
# Loading weights:  83%|████████▎ | 166/199 [00:00<00:00, 2876.35it/s, Materializing param=encoder.layer.10.attention.output.LayerNorm.bias]
# Loading weights:  84%|████████▍ | 167/199 [00:00<00:00, 2884.01it/s, Materializing param=encoder.layer.10.attention.output.LayerNorm.weight]
# Loading weights:  84%|████████▍ | 167/199 [00:00<00:00, 2878.18it/s, Materializing param=encoder.layer.10.attention.output.LayerNorm.weight]
# Loading weights:  84%|████████▍ | 168/199 [00:00<00:00, 2886.00it/s, Materializing param=encoder.layer.10.attention.output.dense.bias]
# Loading weights:  84%|████████▍ | 168/199 [00:00<00:00, 2879.89it/s, Materializing param=encoder.layer.10.attention.output.dense.bias]
# Loading weights:  85%|████████▍ | 169/199 [00:00<00:00, 2887.74it/s, Materializing param=encoder.layer.10.attention.output.dense.weight]
# Loading weights:  85%|████████▍ | 169/199 [00:00<00:00, 2880.74it/s, Materializing param=encoder.layer.10.attention.output.dense.weight]
# Loading weights:  85%|████████▌ | 170/199 [00:00<00:00, 2888.24it/s, Materializing param=encoder.layer.10.attention.self.key.bias]
# Loading weights:  85%|████████▌ | 170/199 [00:00<00:00, 2882.69it/s, Materializing param=encoder.layer.10.attention.self.key.bias]
# Loading weights:  86%|████████▌ | 171/199 [00:00<00:00, 2890.51it/s, Materializing param=encoder.layer.10.attention.self.key.weight]
# Loading weights:  86%|████████▌ | 171/199 [00:00<00:00, 2885.10it/s, Materializing param=encoder.layer.10.attention.self.key.weight]
# Loading weights:  86%|████████▋ | 172/199 [00:00<00:00, 2892.52it/s, Materializing param=encoder.layer.10.attention.self.query.bias]
# Loading weights:  86%|████████▋ | 172/199 [00:00<00:00, 2886.05it/s, Materializing param=encoder.layer.10.attention.self.query.bias]
# Loading weights:  87%|████████▋ | 173/199 [00:00<00:00, 2891.93it/s, Materializing param=encoder.layer.10.attention.self.query.weight]
# Loading weights:  87%|████████▋ | 173/199 [00:00<00:00, 2886.25it/s, Materializing param=encoder.layer.10.attention.self.query.weight]
# Loading weights:  87%|████████▋ | 174/199 [00:00<00:00, 2894.17it/s, Materializing param=encoder.layer.10.attention.self.value.bias]
# Loading weights:  87%|████████▋ | 174/199 [00:00<00:00, 2888.82it/s, Materializing param=encoder.layer.10.attention.self.value.bias]
# Loading weights:  88%|████████▊ | 175/199 [00:00<00:00, 2895.99it/s, Materializing param=encoder.layer.10.attention.self.value.weight]
# Loading weights:  88%|████████▊ | 175/199 [00:00<00:00, 2889.98it/s, Materializing param=encoder.layer.10.attention.self.value.weight]
# Loading weights:  88%|████████▊ | 176/199 [00:00<00:00, 2896.99it/s, Materializing param=encoder.layer.10.intermediate.dense.bias]
# Loading weights:  88%|████████▊ | 176/199 [00:00<00:00, 2891.76it/s, Materializing param=encoder.layer.10.intermediate.dense.bias]
# Loading weights:  89%|████████▉ | 177/199 [00:00<00:00, 2900.29it/s, Materializing param=encoder.layer.10.intermediate.dense.weight]
# Loading weights:  89%|████████▉ | 177/199 [00:00<00:00, 2895.53it/s, Materializing param=encoder.layer.10.intermediate.dense.weight]
# Loading weights:  89%|████████▉ | 178/199 [00:00<00:00, 2903.87it/s, Materializing param=encoder.layer.10.output.LayerNorm.bias]
# Loading weights:  89%|████████▉ | 178/199 [00:00<00:00, 2899.00it/s, Materializing param=encoder.layer.10.output.LayerNorm.bias]
# Loading weights:  90%|████████▉ | 179/199 [00:00<00:00, 2906.42it/s, Materializing param=encoder.layer.10.output.LayerNorm.weight]
# Loading weights:  90%|████████▉ | 179/199 [00:00<00:00, 2900.65it/s, Materializing param=encoder.layer.10.output.LayerNorm.weight]
# Loading weights:  90%|█████████ | 180/199 [00:00<00:00, 2907.97it/s, Materializing param=encoder.layer.10.output.dense.bias]
# Loading weights:  90%|█████████ | 180/199 [00:00<00:00, 2902.67it/s, Materializing param=encoder.layer.10.output.dense.bias]
# Loading weights:  91%|█████████ | 181/199 [00:00<00:00, 2910.33it/s, Materializing param=encoder.layer.10.output.dense.weight]
# Loading weights:  91%|█████████ | 181/199 [00:00<00:00, 2904.79it/s, Materializing param=encoder.layer.10.output.dense.weight]
# Loading weights:  91%|█████████▏| 182/199 [00:00<00:00, 2912.19it/s, Materializing param=encoder.layer.11.attention.output.LayerNorm.bias]
# Loading weights:  91%|█████████▏| 182/199 [00:00<00:00, 2906.05it/s, Materializing param=encoder.layer.11.attention.output.LayerNorm.bias]
# Loading weights:  92%|█████████▏| 183/199 [00:00<00:00, 2912.82it/s, Materializing param=encoder.layer.11.attention.output.LayerNorm.weight]
# Loading weights:  92%|█████████▏| 183/199 [00:00<00:00, 2907.34it/s, Materializing param=encoder.layer.11.attention.output.LayerNorm.weight]
# Loading weights:  92%|█████████▏| 184/199 [00:00<00:00, 2912.38it/s, Materializing param=encoder.layer.11.attention.output.dense.bias]
# Loading weights:  92%|█████████▏| 184/199 [00:00<00:00, 2905.25it/s, Materializing param=encoder.layer.11.attention.output.dense.bias]
# Loading weights:  93%|█████████▎| 185/199 [00:00<00:00, 2909.99it/s, Materializing param=encoder.layer.11.attention.output.dense.weight]
# Loading weights:  93%|█████████▎| 185/199 [00:00<00:00, 2903.41it/s, Materializing param=encoder.layer.11.attention.output.dense.weight]
# Loading weights:  93%|█████████▎| 186/199 [00:00<00:00, 2909.57it/s, Materializing param=encoder.layer.11.attention.self.key.bias]
# Loading weights:  93%|█████████▎| 186/199 [00:00<00:00, 2904.22it/s, Materializing param=encoder.layer.11.attention.self.key.bias]
# Loading weights:  94%|█████████▍| 187/199 [00:00<00:00, 2911.09it/s, Materializing param=encoder.layer.11.attention.self.key.weight]
# Loading weights:  94%|█████████▍| 187/199 [00:00<00:00, 2905.13it/s, Materializing param=encoder.layer.11.attention.self.key.weight]
# Loading weights:  94%|█████████▍| 188/199 [00:00<00:00, 2911.71it/s, Materializing param=encoder.layer.11.attention.self.query.bias]
# Loading weights:  94%|█████████▍| 188/199 [00:00<00:00, 2906.92it/s, Materializing param=encoder.layer.11.attention.self.query.bias]
# Loading weights:  95%|█████████▍| 189/199 [00:00<00:00, 2914.65it/s, Materializing param=encoder.layer.11.attention.self.query.weight]
# Loading weights:  95%|█████████▍| 189/199 [00:00<00:00, 2910.16it/s, Materializing param=encoder.layer.11.attention.self.query.weight]
# Loading weights:  95%|█████████▌| 190/199 [00:00<00:00, 2918.26it/s, Materializing param=encoder.layer.11.attention.self.value.bias]
# Loading weights:  95%|█████████▌| 190/199 [00:00<00:00, 2913.84it/s, Materializing param=encoder.layer.11.attention.self.value.bias]
# Loading weights:  96%|█████████▌| 191/199 [00:00<00:00, 2921.41it/s, Materializing param=encoder.layer.11.attention.self.value.weight]
# Loading weights:  96%|█████████▌| 191/199 [00:00<00:00, 2916.87it/s, Materializing param=encoder.layer.11.attention.self.value.weight]
# Loading weights:  96%|█████████▋| 192/199 [00:00<00:00, 2923.36it/s, Materializing param=encoder.layer.11.intermediate.dense.bias]
# Loading weights:  96%|█████████▋| 192/199 [00:00<00:00, 2918.04it/s, Materializing param=encoder.layer.11.intermediate.dense.bias]
# Loading weights:  97%|█████████▋| 193/199 [00:00<00:00, 2924.94it/s, Materializing param=encoder.layer.11.intermediate.dense.weight]
# Loading weights:  97%|█████████▋| 193/199 [00:00<00:00, 2919.98it/s, Materializing param=encoder.layer.11.intermediate.dense.weight]
# Loading weights:  97%|█████████▋| 194/199 [00:00<00:00, 2927.02it/s, Materializing param=encoder.layer.11.output.LayerNorm.bias]
# Loading weights:  97%|█████████▋| 194/199 [00:00<00:00, 2921.62it/s, Materializing param=encoder.layer.11.output.LayerNorm.bias]
# Loading weights:  98%|█████████▊| 195/199 [00:00<00:00, 2927.61it/s, Materializing param=encoder.layer.11.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 195/199 [00:00<00:00, 2922.48it/s, Materializing param=encoder.layer.11.output.LayerNorm.weight]
# Loading weights:  98%|█████████▊| 196/199 [00:00<00:00, 2929.27it/s, Materializing param=encoder.layer.11.output.dense.bias]
# Loading weights:  98%|█████████▊| 196/199 [00:00<00:00, 2924.36it/s, Materializing param=encoder.layer.11.output.dense.bias]
# Loading weights:  99%|█████████▉| 197/199 [00:00<00:00, 2931.37it/s, Materializing param=encoder.layer.11.output.dense.weight]
# Loading weights:  99%|█████████▉| 197/199 [00:00<00:00, 2925.81it/s, Materializing param=encoder.layer.11.output.dense.weight]
# Loading weights:  99%|█████████▉| 198/199 [00:00<00:00, 2932.47it/s, Materializing param=pooler.dense.bias]
# Loading weights:  99%|█████████▉| 198/199 [00:00<00:00, 2926.90it/s, Materializing param=pooler.dense.bias]
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2933.89it/s, Materializing param=pooler.dense.weight]
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2929.29it/s, Materializing param=pooler.dense.weight]
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2919.67it/s, Materializing param=pooler.dense.weight]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
#
# ✅ Vector comparison testi tamamlandı
# 📄 JSONL: ./outputs/Bio-Bert_davekevin_real_vs_black_vectors.jsonl
# 🧠 PT   : ./outputs/Bio-Bert_davekevin_real_vs_black_vectors.pt
#
# 📌 İlk 3 satır:
# {"index": 0, "question": "What is a pleural effusion?", "image_name": "test/medvqa_test_000205.png", "image_path": "datasets/daveKevin_images/test/medvqa_test_000205.png", "mode_real": "question + real_image", "mode_black": "question + black_image", "cosine_similarity": 0.9999855160713196, "l2_distance": 0.036602843552827835, "delta_norm": 0.036602843552827835, "real_vector_norm": 6.79587459564209, "black_vector_norm": 6.794904708862305, "real_vector_preview": [-0.18565361201763153, 0.4887978434562683, 0.08367685973644257, 0.03428094834089279, 0.009228350594639778, 0.03579064458608627, -0.04886297509074211, -0.2648111581802368, -0.0779082328081131, 0.045724742114543915, -0.009225321933627129, -0.23471413552761078], "black_vector_preview": [-0.1839398592710495, 0.48765063285827637, 0.08336695283651352, 0.03637760877609253, 0.00809410773217678, 0.036696113646030426, -0.04934421181678772, -0.2657928168773651, -0.07857786864042282, 0.04550018906593323, -0.00927008781582117, -0.23439255356788635]}
# {"index": 1, "question": "What treatment options would you consider for a patient with this imaging finding?", "image_name": "test/medvqa_test_000573.png", "image_path": "datasets/daveKevin_images/test/medvqa_test_000573.png", "mode_real": "question + real_image", "mode_black": "question + black_image", "cosine_similarity": 0.9999852180480957, "l2_distance": 0.03687552735209465, "delta_norm": 0.03687552735209465, "real_vector_norm": 6.79517126083374, "black_vector_norm": 6.794904708862305, "real_vector_preview": [-0.18447884917259216, 0.4879685044288635, 0.08381235599517822, 0.03447187691926956, 0.007911615073680878, 0.036140769720077515, -0.04928506538271904, -0.2660455107688904, -0.07785917818546295, 0.044929247349500656, -0.008251858875155449, -0.23474276065826416], "black_vector_preview": [-0.1839398592710495, 0.48765063285827637, 0.08336695283651352, 0.03637760877609253, 0.00809410773217678, 0.036696113646030426, -0.04934421181678772, -0.2657928168773651, -0.07857786864042282, 0.04550018906593323, -0.00927008781582117, -0.23439255356788635]}
# {"index": 2, "question": "What can you see in the image?", "image_name": "test/medvqa_test_000051.png", "image_path": "datasets/daveKevin_images/test/medvqa_test_000051.png", "mode_real": "question + real_image", "mode_black": "question + black_image", "cosine_similarity": 0.999986469745636, "l2_distance": 0.03505413979291916, "delta_norm": 0.03505413979291916, "real_vector_norm": 6.732691764831543, "black_vector_norm": 6.733531951904297, "real_vector_preview": [-0.18568596243858337, 0.5304676294326782, 0.09270986169576645, 0.036649707704782486, 0.05011875182390213, 0.050994157791137695, -0.014646394178271294, -0.28218787908554077, -0.043383728712797165, 0.0055246008560061455, -0.008844478987157345, -0.2135816514492035], "black_vector_preview": [-0.18598119914531708, 0.5309901237487793, 0.09198548644781113, 0.03920741006731987, 0.04855649173259735, 0.05061013624072075, -0.01600133255124092, -0.2827897071838379, -0.04354768991470337, 0.00532026682049036, -0.009756969287991524, -0.21258942782878876]}

# %% [markdown]
# ## 4. Model Değerlendirme ve CSV Export

# %%
# İlk olarak eval_DiffuVQA.py ile değerlendir.

CURRENT_SAMPLE_FILENAME = f"ema_0.9999_004000.pt.seed102_step0_samplestep{SAMPLE_STEP}_bsize{BATCH_SIZE}.jsonl"

# !python eval_DiffuVQA.py --folder {SAMPLE_FOLDER} --filename {"ema_0.9999_004000.pt.seed102_step0_samplestep50_bsize2"}
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Enhanced metrics loaded successfully!
# Excel export module loaded successfully!
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# save tokenizer to diffuvqa/config
# /content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/DiffuVQA/eval_DiffuVQA.py", line 218, in <module>
#     with open(files[0], 'r') as f:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/DiffuVQA/samples/davekevin/bio-bert/ema_0.9999_004000.pt.seed102_step0_samplestep50_bsize2'

# %%
# Değerlendirme fonksiyonları
from torchmetrics.text.rouge import ROUGEScore
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk

# NLTK veri setlerini indir
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

rougeScore = ROUGEScore()

def get_bleu(recover, reference, n=1):
    """BLEU-n score"""
    weights = tuple((1.0 / n for _ in range(n)))
    return sentence_bleu([reference.split()], recover.split(),
                        weights=weights,
                        smoothing_function=SmoothingFunction().method4)

def rouge_l_score(prediction, reference):
    """ROUGE-L score"""
    scores = rougeScore(prediction, reference)
    return scores['rougeL_fmeasure'].item()

def calculate_meteor(prediction, reference):
    """METEOR score"""
    return meteor_score([word_tokenize(reference)], word_tokenize(prediction))

def cider_score(predictions, references):
    """CIDEr-like score using TF-IDF cosine similarity"""
    if not predictions or not references:
        return 0.0
    try:
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(predictions + references)
        n_pred = len(predictions)
        pred_vectors = tfidf_matrix[:n_pred]
        ref_vectors = tfidf_matrix[n_pred:]
        similarities = cosine_similarity(pred_vectors, ref_vectors)
        return similarities.diagonal().mean()
    except:
        return 0.0

print("✅ Değerlendirme fonksiyonları hazır")

# %%
def evaluate_and_export_csv(sample_files, output_csv="evaluation_results.csv", dataset_file="datasets/test.jsonl",
                            model_label="DiffuVQA", dataset_label="SLAKE"):
    """
    Örneklenmiş model çıktılarını değerlendir ve CSV'ye kaydet

    Args:
        sample_files: JSONL formatında örnek dosyaları (liste veya tek dosya)
        output_csv: Çıktı CSV dosya yolu
        dataset_file: Original dataset (answer_type bilgisi için)
        model_label: Raporda görünecek model ismi
        dataset_label: Raporda görünecek dataset ismi
    """
    if isinstance(sample_files, str):
        sample_files = [sample_files]

    # Dataset'ten answer_type mapping'i oluştur
    print(f"📂 Dataset'ten answer_type bilgisi yükleniyor: {dataset_file}")
    answer_type_map = {}
    try:
        with open(dataset_file, 'r', encoding='utf-8') as f:
            for line in f:
                data = json.loads(line)
                qid = data.get('qid')
                question = data.get('question', '').strip().lower()
                answer_type = data.get('answer_type', 'UNKNOWN')

                if qid:
                    answer_type_map[qid] = answer_type
                if question:
                    answer_type_map[question] = answer_type
        print(f"✅ {len(answer_type_map)} answer_type mapping yüklendi")
    except Exception as e:
        print(f"⚠️ Dataset yüklenemedi: {e}")
        answer_type_map = {}

    all_results = []

    for sample_file in sample_files:
        print(f"\n📊 Değerlendiriliyor: {sample_file}")

        samples = []
        with open(sample_file, 'r', encoding='utf-8') as f:
            for line in f:
                samples.append(json.loads(line))

        print(f"✅ {len(samples)} satır okundu")

        bleu1_scores = []
        rougeL_scores = []
        meteor_scores = []
        f1_scores = []
        predictions = []
        references = []

        total_samples = 0
        correct_all = 0
        correct_yn = 0
        correct_oe = 0
        count_yn = 0
        count_oe = 0
        empty_count = 0

        for sample in samples:
            pred = (sample.get('generate_answer') or
                   sample.get('recover') or
                   sample.get('generated_answer') or
                   sample.get('prediction') or '').strip()

            ref = (sample.get('reference_answer') or
                  sample.get('reference') or
                  sample.get('answer') or '').strip()

            q_type = sample.get('answer_type', 'UNKNOWN')

            if q_type == 'UNKNOWN':
                qid = sample.get('qid')
                question = sample.get('question', '').strip().lower()

                if qid and qid in answer_type_map:
                    q_type = answer_type_map[qid]
                elif question and question in answer_type_map:
                    q_type = answer_type_map[question]

            if not ref:
                continue

            if not pred:
                empty_count += 1
                pred = "[EMPTY]"

            predictions.append(pred)
            references.append(ref)

            em = 1.0 if pred.lower().strip() == ref.lower().strip() else 0.0

            total_samples += 1
            if em == 1.0:
                correct_all += 1
                if q_type == 'CLOSED':
                    correct_yn += 1
                elif q_type == 'OPEN':
                    correct_oe += 1

            if q_type == 'CLOSED':
                count_yn += 1
            elif q_type == 'OPEN':
                count_oe += 1

            if pred != "[EMPTY]":
                pred_tokens = set(pred.lower().split())
                ref_tokens = set(ref.lower().split())
                if len(pred_tokens) == 0 or len(ref_tokens) == 0:
                    f1 = 0.0
                else:
                    precision = len(pred_tokens & ref_tokens) / len(pred_tokens)
                    recall = len(pred_tokens & ref_tokens) / len(ref_tokens)
                    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
                f1_scores.append(f1)
            else:
                f1_scores.append(0.0)

            bleu1_scores.append(get_bleu(pred, ref, n=1) if pred != "[EMPTY]" else 0.0)
            rougeL_scores.append(rouge_l_score(pred, ref) if pred != "[EMPTY]" else 0.0)
            meteor_scores.append(calculate_meteor(pred, ref) if pred != "[EMPTY]" else 0.0)

        cider = cider_score(predictions, references) if predictions else 0.0

        print("⏳ BERTScore hesaplanıyor...")
        try:
            from bert_score import score as bert_score_fn
            valid_preds = [p for p in predictions if p != "[EMPTY]"]
            valid_refs = [r for i, r in enumerate(references) if predictions[i] != "[EMPTY]"]

            if valid_preds and valid_refs:
                bert_precision, bert_recall, bert_f1 = bert_score_fn(
                    valid_preds, valid_refs, lang='en', verbose=False, device='cuda' if torch.cuda.is_available() else 'cpu'
                )
                bert_f1_score = bert_f1.mean().item()
            else:
                bert_f1_score = 0.0
        except Exception as e:
            print(f"⚠️ BERTScore hesaplanamadı: {e}")
            bert_f1_score = 0.0

        print(f"\n📋 Answer Type Dağılımı:")
        print(f"  CLOSED sorular: {count_yn}")
        print(f"  OPEN sorular: {count_oe}")
        print(f"  UNKNOWN: {total_samples - count_yn - count_oe}")

        sample_folder_path = os.path.dirname(sample_file) if os.path.dirname(sample_file) else "./samples"

        results = {
            'model_name': model_label,
            'dataset_name': dataset_label,
            'export_date': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'overall_accuracy': correct_all / total_samples if total_samples > 0 else 0.0,
            'yes_no_accuracy': correct_yn / count_yn if count_yn > 0 else 0.0,
            'open_ended_accuracy': correct_oe / count_oe if count_oe > 0 else 0.0,
            'bleu_1_score': np.mean(bleu1_scores) if bleu1_scores else 0.0,
            'rouge_l_score': np.mean(rougeL_scores) if rougeL_scores else 0.0,
            'meteor_score': np.mean(meteor_scores) if meteor_scores else 0.0,
            'cider_score': cider,
            'bert_score': bert_f1_score,
            'f1_score': np.mean(f1_scores) if f1_scores else 0.0,
            'additional_info': f"Empty: {empty_count} ({100*empty_count/total_samples:.1f}%)" if total_samples > 0 else "",
            'Sample Folder': sample_folder_path,
            'Total Samples': total_samples,
            'Evaluation Date': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'File Count': 1
        }

        all_results.append(results)

        print(f"\n📈 Sonuçlar - {os.path.basename(sample_file)}:")
        print(f"  Total Samples: {results['Total Samples']}")
        print(f"  Overall Accuracy: {results['overall_accuracy']:.4f}")
        print(f"  Yes/No Accuracy: {results['yes_no_accuracy']:.4f}")
        print(f"  Open-Ended Accuracy: {results['open_ended_accuracy']:.4f}")
        print(f"  F1 Score: {results['f1_score']:.4f}")
        print(f"  BLEU-1: {results['bleu_1_score']:.4f}")
        print(f"  ROUGE-L: {results['rouge_l_score']:.4f}")
        print(f"  METEOR: {results['meteor_score']:.4f}")
        print(f"  CIDEr: {results['cider_score']:.4f}")
        print(f"  BERTScore: {results['bert_score']:.4f}")

    df = pd.DataFrame(all_results)
    df.to_csv(output_csv, index=False, encoding='utf-8')
    print(f"\n✅ Sonuçlar CSV'ye kaydedildi: {output_csv}")
    return df

print("✅ CSV export fonksiyonu hazır")

# %%
# Tüm örnek dosyalarını değerlendir
sample_files = glob.glob(f"{SAMPLE_FOLDER}/*.jsonl")

os.makedirs("./reports", exist_ok=True)

if not sample_files:
    print("⚠️ Örnek dosyası bulunamadı!")
    print(f"💡 Lütfen önce örnekleme hücresini çalıştırın.")
    print(f"   Checkpoint: {CHECKPOINT_PATH}/ema_0.9999_*.pt")
else:
    print(f"📂 {len(sample_files)} örnek dosyası bulundu")
    results_df = evaluate_and_export_csv(
        sample_files,
        output_csv=OUTPUT_CSV,
        model_label=MODEL_LABEL,
        dataset_label=DATASET,
    )
    print("\n" + "="*80)
    print("📊 TÜM SONUÇLAR:")
    print("="*80)
    display(results_df)

# %% [markdown]
# ## 5. Sonuçları İndir

# %%
# CSV dosyasını Google Drive'a kaydet ve indir
from google.colab import files

os.makedirs(DRIVE_RESULTS_PATH, exist_ok=True)

if os.path.exists(OUTPUT_CSV):
    shutil.copy(OUTPUT_CSV, DRIVE_RESULTS_PATH)
    print(f"✅ CSV Google Drive'a kaydedildi: {DRIVE_RESULTS_PATH}")
    files.download(OUTPUT_CSV)
    print(f"✅ {OUTPUT_CSV} bilgisayarınıza indirildi")
else:
    print(f"⚠️ CSV dosyası bulunamadı: {OUTPUT_CSV}")
    print("💡 Lütfen önce değerlendirme hücresini çalıştırın.")

# Checkpoint'leri de Drive'a yedekle (opsiyonel)
print("\n💾 Checkpoint'leri yedeklemek ister misiniz?")
print(f"   # !cp -r {CHECKPOINT_PATH} /content/drive/MyDrive/DiffuVQA_Checkpoints/")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sonuçları görselleştir
if 'results_df' in locals() and len(results_df) > 0:
    # Metrik sütunlarını seç
    fig, axes = plt.subplots(2, 1, figsize=(14, 10))

    # Accuracy metrikleri (CLOSED ve OPEN)
    accuracy_cols = ['overall_accuracy', 'yes_no_accuracy', 'open_ended_accuracy']
    results_df[accuracy_cols].iloc[0].plot(kind='bar', ax=axes[0], color='skyblue')
    axes[0].set_title('Accuracy Metrics (CLOSED=Yes/No, OPEN=Open-Ended)', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('Score', fontsize=12)
    axes[0].set_ylim([0, 1])
    axes[0].grid(axis='y', alpha=0.3)
    axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha='right')

    # NLG ve Semantic metrikleri
    nlg_cols = ['f1_score', 'bleu_1_score', 'rouge_l_score', 'meteor_score', 'cider_score', 'bert_score']
    results_df[nlg_cols].iloc[0].plot(kind='bar', ax=axes[1], color='lightcoral')
    axes[1].set_title('NLG & Semantic Similarity Metrics', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('Score', fontsize=12)
    axes[1].set_ylim([0, 1])
    axes[1].grid(axis='y', alpha=0.3)
    axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=45, ha='right')

    plt.tight_layout()
    plt.savefig('./reports/metrics_visualization.png', dpi=300, bbox_inches='tight')
    plt.show()

    print("✅ Görselleştirme kaydedildi: ./reports/metrics_visualization.png")
else:
    print("⚠️ Görselleştirme için sonuç bulunamadı.")
    print("💡 Lütfen önce değerlendirme hücresini (Cell 15) çalıştırın.")
